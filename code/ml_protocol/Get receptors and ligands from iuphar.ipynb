# %%
import os
from os import path

import pygtop

from biopandas.pdb import PandasPdb

import pubchempy as pcp
import time

#used on checking the files/folder name
import re
from unidecode import unidecode

# %% [markdown]
# ### FUNCTIONS

# %%
def get_pubchem_id(ligand):
    dbs = ligand.database_links()
    for db in dbs:
        if db.database() == "PubChem CID":
            return db.accession()
        
def update_pdb_obsolete(id_pdb):
    ppdb = PandasPdb().fetch_pdb(id_pdb)
    idx = ppdb.df["OTHERS"]["record_name"] == "OBSLTE"
    if sum(idx) != 0: #if OBSLTE give me the current id
        id_pdb = list(ppdb.df["OTHERS"]["entry"][idx])[0].split(" ")[-1]
        ppdb = PandasPdb().fetch_pdb(id_pdb)
    return([id_pdb, ppdb])

def ismutated(pdb):
    return(any("MUTATION" in e for e in pdb.df["OTHERS"][pdb.df["OTHERS"]["record_name"] == "COMPND"]["entry"]))

# %% [markdown]
# ### Get all receptors of the GPCR family

# %% [markdown]
# Class A: https://www.guidetopharmacology.org/GRAC/GPCRListForward?class=A

# %%
targets = pygtop.get_targets_by({"type": "GPCR"})

# %%
len(targets), targets
# Out:
# (410,
#  [<Target 1 (5-HT<sub>1A</sub> receptor)>,
#   <Target 2 (5-HT<sub>1B</sub> receptor)>,
#   <Target 3 (5-HT<sub>1D</sub> receptor)>,
#   <Target 4 (5-ht<sub>1e</sub> receptor)>,
#   <Target 5 (5-HT<sub>1F</sub> receptor)>,
#   <Target 6 (5-HT<sub>2A</sub> receptor)>,
#   <Target 7 (5-HT<sub>2B</sub> receptor)>,
#   <Target 8 (5-HT<sub>2C</sub> receptor)>,
#   <Target 9 (5-HT<sub>4</sub> receptor)>,
#   <Target 10 (5-HT<sub>5A</sub> receptor)>,
#   <Target 648 (5-ht<sub>5b</sub> receptor)>,
#   <Target 11 (5-HT<sub>6</sub> receptor)>,
#   <Target 12 (5-HT<sub>7</sub> receptor)>,
#   <Target 316 (ACKR1)>,
#   <Target 314 (ACKR2)>,
#   <Target 80 (ACKR3)>,
#   <Target 315 (ACKR4)>,
#   <Target 197 (ADGRA1)>,
#   <Target 198 (ADGRA2)>,
#   <Target 199 (ADGRA3)>,
#   <Target 174 (ADGRB1)>,
#   <Target 175 (ADGRB2)>,
#   <Target 176 (ADGRB3)>,
#   <Target 202 (ADGRD1)>,
#   <Target 204 (ADGRD2)>,
#   <Target 182 (ADGRE1)>,
#   <Target 183 (ADGRE2)>,
#   <Target 184 (ADGRE3)>,
#   <Target 185 (ADGRE4P)>,
#   <Target 177 (ADGRE5)>,
#   <Target 190 (ADGRF1)>,
#   <Target 191 (ADGRF2)>,
#   <Target 193 (ADGRF3)>,
#   <Target 195 (ADGRF4)>,
#   <Target 196 (ADGRF5)>,
#   <Target 186 (ADGRG1)>,
#   <Target 187 (ADGRG2)>,
#   <Target 188 (ADGRG3)>,
#   <Target 192 (ADGRG4)>,
#   <Target 194 (ADGRG5)>,
#   <Target 200 (ADGRG6)>,
#   <Target 201 (ADGRG7)>,
#   <Target 206 (ADGRL1)>,
#   <Target 207 (ADGRL2)>,
#   <Target 208 (ADGRL3)>,
#   <Target 181 (ADGRL4)>,
#   <Target 189 (ADGRV1)>,
#   <Target 22 (&alpha;<sub>1A</sub>-adrenoceptor)>,
#   <Target 23 (&alpha;<sub>1B</sub>-adrenoceptor)>,
#   <Target 24 (&alpha;<sub>1D</sub>-adrenoceptor)>,
#   <Target 25 (&alpha;<sub>2A</sub>-adrenoceptor)>,
#   <Target 26 (&alpha;<sub>2B</sub>-adrenoceptor)>,
#   <Target 27 (&alpha;<sub>2C</sub>-adrenoceptor)>,
#   <Target 49 (AM<sub>1</sub> receptor)>,
#   <Target 50 (AM<sub>2</sub> receptor)>,
#   <Target 44 (AMY<sub>1</sub> receptor)>,
#   <Target 45 (AMY<sub>2</sub> receptor)>,
#   <Target 46 (AMY<sub>3</sub> receptor)>,
#   <Target 36 (apelin receptor)>,
#   <Target 18 (A<sub>1</sub> receptor)>,
#   <Target 19 (A<sub>2A</sub> receptor)>,
#   <Target 20 (A<sub>2B</sub> receptor)>,
#   <Target 21 (A<sub>3</sub> receptor)>,
#   <Target 34 (AT<sub>1</sub> receptor)>,
#   <Target 35 (AT<sub>2</sub> receptor)>,
#   <Target 38 (BB<sub>1</sub> receptor)>,
#   <Target 39 (BB<sub>2</sub> receptor)>,
#   <Target 40 (BB<sub>3</sub> receptor)>,
#   <Target 28 (&beta;<sub>1</sub>-adrenoceptor)>,
#   <Target 29 (&beta;<sub>2</sub>-adrenoceptor)>,
#   <Target 30 (&beta;<sub>3</sub>-adrenoceptor)>,
#   <Target 267 (BLT<sub>1</sub> receptor)>,
#   <Target 268 (BLT<sub>2</sub> receptor)>,
#   <Target 41 (B<sub>1</sub> receptor)>,
#   <Target 42 (B<sub>2</sub> receptor)>,
#   <Target 31 (C3a receptor)>,
#   <Target 32 (C5a<sub>1</sub> receptor)>,
#   <Target 33 (C5a<sub>2</sub> receptor)>,
#   <Target 47 (calcitonin receptor-like receptor)>,
#   <Target 54 (CaS receptor)>,
#   <Target 56 (CB<sub>1</sub> receptor)>,
#   <Target 57 (CB<sub>2</sub> receptor)>,
#   <Target 76 (CCK<sub>1</sub> receptor)>,
#   <Target 77 (CCK<sub>2</sub> receptor)>,
#   <Target 58 (CCR1)>,
#   <Target 67 (CCR10)>,
#   <Target 59 (CCR2)>,
#   <Target 60 (CCR3)>,
#   <Target 61 (CCR4)>,
#   <Target 62 (CCR5)>,
#   <Target 63 (CCR6)>,
#   <Target 64 (CCR7)>,
#   <Target 65 (CCR8)>,
#   <Target 66 (CCR9)>,
#   <Target 78 (CCRL2)>,
#   <Target 48 (CGRP receptor)>,
#   <Target 79 (chemerin receptor 1)>,
#   <Target 82 (chemerin receptor 2)>,
#   <Target 212 (CRF<sub>1</sub> receptor)>,
#   <Target 213 (CRF<sub>2</sub> receptor)>,
#   <Target 43 (CT receptor)>,
#   <Target 68 (CXCR1)>,
#   <Target 69 (CXCR2)>,
#   <Target 70 (CXCR3)>,
#   <Target 71 (CXCR4)>,
#   <Target 72 (CXCR5)>,
#   <Target 73 (CXCR6)>,
#   <Target 74 (CX<sub>3</sub>CR1)>,
#   <Target 269 (CysLT<sub>1</sub> receptor)>,
#   <Target 270 (CysLT<sub>2</sub> receptor)>,
#   <Target 317 (&delta; receptor)>,
#   <Target 338 (DP<sub>1</sub> receptor)>,
#   <Target 339 (DP<sub>2</sub> receptor)>,
#   <Target 214 (D<sub>1</sub> receptor)>,
#   <Target 215 (D<sub>2</sub> receptor)>,
#   <Target 216 (D<sub>3</sub> receptor)>,
#   <Target 217 (D<sub>4</sub> receptor)>,
#   <Target 218 (D<sub>5</sub> receptor)>,
#   <Target 340 (EP<sub>1</sub> receptor)>,
#   <Target 341 (EP<sub>2</sub> receptor)>,
#   <Target 342 (EP<sub>3</sub> receptor)>,
#   <Target 343 (EP<sub>4</sub> receptor)>,
#   <Target 219 (ET<sub>A</sub> receptor)>,
#   <Target 220 (ET<sub>B</sub> receptor)>,
#   <Target 225 (FFA1 receptor)>,
#   <Target 226 (FFA2 receptor)>,
#   <Target 227 (FFA3 receptor)>,
#   <Target 127 (FFA4 receptor)>,
#   <Target 222 (FPR1)>,
#   <Target 223 (FPR2/ALX)>,
#   <Target 224 (FPR3)>,
#   <Target 344 (FP receptor)>,
#   <Target 253 (FSH receptor)>,
#   <Target 238 (FZD<sub>10</sub>)>,
#   <Target 229 (FZD<sub>1</sub>)>,
#   <Target 230 (FZD<sub>2</sub>)>,
#   <Target 231 (FZD<sub>3</sub>)>,
#   <Target 232 (FZD<sub>4</sub>)>,
#   <Target 233 (FZD<sub>5</sub>)>,
#   <Target 234 (FZD<sub>6</sub>)>,
#   <Target 235 (FZD<sub>7</sub>)>,
#   <Target 236 (FZD<sub>8</sub>)>,
#   <Target 237 (FZD<sub>9</sub>)>,
#   <Target 240 (GABA<sub>B1</sub>)>,
#   <Target 241 (GABA<sub>B2</sub>)>,
#   <Target 242 (GABA<sub>B</sub> receptor)>,
#   <Target 243 (GAL<sub>1</sub> receptor)>,
#   <Target 244 (GAL<sub>2</sub> receptor)>,
#   <Target 245 (GAL<sub>3</sub> receptor)>,
#   <Target 246 (ghrelin receptor)>,
#   <Target 247 (GHRH receptor)>,
#   <Target 248 (GIP receptor)>,
#   <Target 249 (GLP-1 receptor)>,
#   <Target 250 (GLP-2 receptor)>,
#   <Target 251 (glucagon receptor)>,
#   <Target 256 (GnRH<sub>1</sub> receptor)>,
#   <Target 257 (GnRH<sub>2</sub> receptor)>,
#   <Target 37 (GPBA receptor)>,
#   <Target 221 (GPER)>,
#   <Target 55 (GPRC6 receptor)>,
#   <Target 311 (HCA<sub>1</sub> receptor)>,
#   <Target 312 (HCA<sub>2</sub> receptor)>,
#   <Target 313 (HCA<sub>3</sub> receptor)>,
#   <Target 262 (H<sub>1</sub> receptor)>,
#   <Target 263 (H<sub>2</sub> receptor)>,
#   <Target 264 (H<sub>3</sub> receptor)>,
#   <Target 265 (H<sub>4</sub> receptor)>,
#   <Target 178 (<i>CELSR1</i>)>,
#   <Target 179 (<i>CELSR2</i>)>,
#   <Target 180 (<i>CELSR3</i>)>,
#   <Target 125 (<i>GPR101</i>)>,
#   <Target 651 (<i>GPR107</i>)>,
#   <Target 126 (<i>GPR119</i>)>,
#   <Target 86 (<i>GPR12</i>)>,
#   <Target 128 (<i>GPR132</i>)>,
#   <Target 129 (<i>GPR135</i>)>,
#   <Target 652 (<i>GPR137</i>)>,
#   <Target 130 (<i>GPR139</i>)>,
#   <Target 131 (<i>GPR141</i>)>,
#   <Target 132 (<i>GPR142</i>)>,
#   <Target 203 (<i>GPR143</i>)>,
#   <Target 133 (<i>GPR146</i>)>,
#   <Target 134 (<i>GPR148</i>)>,
#   <Target 135 (<i>GPR149</i>)>,
#   <Target 136 (<i>GPR150</i>)>,
#   <Target 137 (<i>GPR151</i>)>,
#   <Target 138 (<i>GPR152</i>)>,
#   <Target 139 (<i>GPR153</i>)>,
#   <Target 209 (<i>GPR156</i>)>,
#   <Target 205 (<i>GPR157</i>)>,
#   <Target 210 (<i>GPR158</i>)>,
#   <Target 87 (<i>GPR15</i>)>,
#   <Target 140 (<i>GPR160</i>)>,
#   <Target 141 (<i>GPR161</i>)>,
#   <Target 142 (<i>GPR162</i>)>,
#   <Target 143 (<i>GPR171</i>)>,
#   <Target 144 (<i>GPR173</i>)>,
#   <Target 145 (<i>GPR174</i>)>,
#   <Target 637 (<i>GPR176</i>)>,
#   <Target 211 (<i>GPR179</i>)>,
#   <Target 88 (<i>GPR17</i>)>,
#   <Target 146 (<i>GPR182</i>)>,
#   <Target 81 (<i>GPR183</i>)>,
#   <Target 89 (<i>GPR18</i>)>,
#   <Target 90 (<i>GPR19</i>)>,
#   <Target 91 (<i>GPR20</i>)>,
#   <Target 92 (<i>GPR21</i>)>,
#   <Target 93 (<i>GPR22</i>)>,
#   <Target 95 (<i>GPR25</i>)>,
#   <Target 96 (<i>GPR26</i>)>,
#   <Target 97 (<i>GPR27</i>)>,
#   <Target 98 (<i>GPR31</i>)>,
#   <Target 99 (<i>GPR32</i>)>,
#   <Target 100 (<i>GPR33</i>)>,
#   <Target 101 (<i>GPR34</i>)>,
#   <Target 102 (<i>GPR35</i>)>,
#   <Target 103 (<i>GPR37</i>)>,
#   <Target 104 (<i>GPR37L1</i>)>,
#   <Target 105 (<i>GPR39</i>)>,
#   <Target 83 (<i>GPR3</i>)>,
#   <Target 228 (<i>GPR42</i>)>,
#   <Target 106 (<i>GPR45</i>)>,
#   <Target 84 (<i>GPR4</i>)>,
#   <Target 107 (<i>GPR50</i>)>,
#   <Target 108 (<i>GPR52</i>)>,
#   <Target 109 (<i>GPR55</i>)>,
#   <Target 110 (<i>GPR61</i>)>,
#   <Target 111 (<i>GPR62</i>)>,
#   <Target 112 (<i>GPR63</i>)>,
#   <Target 113 (<i>GPR65</i>)>,
#   <Target 114 (<i>GPR68</i>)>,
#   <Target 85 (<i>GPR6</i>)>,
#   <Target 115 (<i>GPR75</i>)>,
#   <Target 116 (<i>GPR78</i>)>,
#   <Target 117 (<i>GPR79</i>)>,
#   <Target 118 (<i>GPR82</i>)>,
#   <Target 119 (<i>GPR83</i>)>,
#   <Target 120 (<i>GPR84</i>)>,
#   <Target 121 (<i>GPR85</i>)>,
#   <Target 122 (<i>GPR87</i>)>,
#   <Target 123 (<i>GPR88</i>)>,
#   <Target 258 (<i>GPRC5A</i>)>,
#   <Target 259 (<i>GPRC5B</i>)>,
#   <Target 260 (<i>GPRC5C</i>)>,
#   <Target 261 (<i>GPRC5D</i>)>,
#   <Target 147 (<i>LGR4</i>)>,
#   <Target 148 (<i>LGR5</i>)>,
#   <Target 149 (<i>LGR6</i>)>,
#   <Target 150 (<i>MAS1</i>)>,
#   <Target 151 (<i>MAS1L</i>)>,
#   <Target 152 (<i>MRGPRD</i>)>,
#   <Target 153 (<i>MRGPRE</i>)>,
#   <Target 154 (<i>MRGPRF</i>)>,
#   <Target 155 (<i>MRGPRG</i>)>,
#   <Target 156 (<i>MRGPRX1</i>)>,
#   <Target 157 (<i>MRGPRX2</i>)>,
#   <Target 158 (<i>MRGPRX3</i>)>,
#   <Target 159 (<i>MRGPRX4</i>)>,
#   <Target 2961 (<i>OPN1LW</i>)>,
#   <Target 2962 (<i>OPN1MW</i>)>,
#   <Target 2960 (<i>OPN1SW</i>)>,
#   <Target 160 (<i>OPN3</i>)>,
#   <Target 2758 (<i>OPN4</i>)>,
#   <Target 161 (<i>OPN5</i>)>,
#   <Target 653 (<i>OR51E1</i>)>,
#   <Target 165 (<i>P2RY10</i>)>,
#   <Target 164 (<i>P2RY8</i>)>,
#   <Target 345 (IP receptor)>,
#   <Target 167 (<i>TAAR2</i>)>,
#   <Target 168 (<i>TAAR3</i>)>,
#   <Target 169 (<i>TAAR4P </i>)>,
#   <Target 170 (<i>TAAR5</i>)>,
#   <Target 171 (<i>TAAR6</i>)>,
#   <Target 172 (<i>TAAR8</i>)>,
#   <Target 173 (<i>TAAR9</i>)>,
#   <Target 656 (<i>TAS1R1</i>)>,
#   <Target 657 (<i>TAS1R2</i>)>,
#   <Target 658 (<i>TAS1R3</i>)>,
#   <Target 666 (<i>TAS2R10</i>)>,
#   <Target 667 (<i>TAS2R13</i>)>,
#   <Target 668 (<i>TAS2R14</i>)>,
#   <Target 669 (<i>TAS2R16</i>)>,
#   <Target 670 (<i>TAS2R19</i>)>,
#   <Target 659 (<i>TAS2R1</i>)>,
#   <Target 671 (<i>TAS2R20</i>)>,
#   <Target 673 (<i>TAS2R30</i>)>,
#   <Target 674 (<i>TAS2R31</i>)>,
#   <Target 682 (<i>TAS2R38</i>)>,
#   <Target 675 (<i>TAS2R39</i>)>,
#   <Target 660 (<i>TAS2R3</i>)>,
#   <Target 676 (<i>TAS2R40</i>)>,
#   <Target 680 (<i>TAS2R41</i>)>,
#   <Target 672 (<i>TAS2R42</i>)>,
#   <Target 678 (<i>TAS2R43</i>)>,
#   <Target 2828 (<i>TAS2R45</i>)>,
#   <Target 679 (<i>TAS2R46</i>)>,
#   <Target 661 (<i>TAS2R4</i>)>,
#   <Target 677 (<i>TAS2R50</i>)>,
#   <Target 662 (<i>TAS2R5</i>)>,
#   <Target 681 (<i>TAS2R60</i>)>,
#   <Target 663 (<i>TAS2R7</i>)>,
#   <Target 664 (<i>TAS2R8</i>)>,
#   <Target 665 (<i>TAS2R9</i>)>,
#   <Target 655 (<i>TPRA1</i>)>,
#   <Target 318 (&kappa; receptor)>,
#   <Target 266 (kisspeptin receptor)>,
#   <Target 254 (LH receptor)>,
#   <Target 272 (LPA<sub>1</sub> receptor)>,
#   <Target 273 (LPA<sub>2</sub> receptor)>,
#   <Target 274 (LPA<sub>3</sub> receptor)>,
#   <Target 94 (LPA<sub>4</sub> receptor)>,
#   <Target 124 (LPA<sub>5</sub> receptor)>,
#   <Target 163 (LPA<sub>6</sub> receptor)>,
#   <Target 280 (MCH<sub>1</sub> receptor)>,
#   <Target 281 (MCH<sub>2</sub> receptor)>,
#   <Target 282 (MC<sub>1</sub> receptor)>,
#   <Target 283 (MC<sub>2</sub> receptor)>,
#   <Target 284 (MC<sub>3</sub> receptor)>,
#   <Target 285 (MC<sub>4</sub> receptor)>,
#   <Target 286 (MC<sub>5</sub> receptor)>,
#   <Target 289 (mGlu<sub>1</sub> receptor)>,
#   <Target 290 (mGlu<sub>2</sub> receptor)>,
#   <Target 291 (mGlu<sub>3</sub> receptor)>,
#   <Target 292 (mGlu<sub>4</sub> receptor)>,
#   <Target 293 (mGlu<sub>5</sub> receptor)>,
#   <Target 294 (mGlu<sub>6</sub> receptor)>,
#   <Target 295 (mGlu<sub>7</sub> receptor)>,
#   <Target 296 (mGlu<sub>8</sub> receptor)>,
#   <Target 297 (motilin receptor)>,
#   <Target 13 (M<sub>1</sub> receptor)>,
#   <Target 14 (M<sub>2</sub> receptor)>,
#   <Target 15 (M<sub>3</sub> receptor)>,
#   <Target 16 (M<sub>4</sub> receptor)>,
#   <Target 17 (M<sub>5</sub> receptor)>,
#   <Target 287 (MT<sub>1</sub> receptor)>,
#   <Target 288 (MT<sub>2</sub> receptor)>,
#   <Target 319 (&mu; receptor)>,
#   <Target 360 (NK<sub>1</sub> receptor)>,
#   <Target 361 (NK<sub>2</sub> receptor)>,
#   <Target 362 (NK<sub>3</sub> receptor)>,
#   <Target 298 (NMU1 receptor)>,
#   <Target 299 (NMU2 receptor)>,
#   <Target 320 (NOP receptor)>,
#   <Target 303 (NPBW1 receptor)>,
#   <Target 304 (NPBW2 receptor)>,
#   <Target 300 (NPFF1 receptor)>,
#   <Target 301 (NPFF2 receptor)>,
#   <Target 302 (NPS receptor)>,
#   <Target 309 (NTS<sub>1</sub> receptor)>,
#   <Target 310 (NTS<sub>2</sub> receptor)>,
#   <Target 369 (OT receptor)>,
#   <Target 271 (OXE receptor)>,
#   <Target 162 (oxoglutarate receptor)>,
#   <Target 321 (OX<sub>1</sub> receptor)>,
#   <Target 322 (OX<sub>2</sub> receptor)>,
#   <Target 327 (P2Y<sub>11</sub> receptor)>,
#   <Target 328 (P2Y<sub>12</sub> receptor)>,
#   <Target 329 (P2Y<sub>13</sub> receptor)>,
#   <Target 330 (P2Y<sub>14</sub> receptor)>,
#   <Target 323 (P2Y<sub>1</sub> receptor)>,
#   <Target 324 (P2Y<sub>2</sub> receptor)>,
#   <Target 325 (P2Y<sub>4</sub> receptor)>,
#   <Target 326 (P2Y<sub>6</sub> receptor)>,
#   <Target 370 (PAC<sub>1</sub> receptor)>,
#   <Target 334 (PAF receptor)>,
#   <Target 347 (PAR1)>,
#   <Target 348 (PAR2)>,
#   <Target 349 (PAR3)>,
#   <Target 350 (PAR4)>,
#   <Target 335 (PKR<sub>1</sub>)>,
#   <Target 336 (PKR<sub>2</sub>)>,
#   <Target 337 (PrRP receptor)>,
#   <Target 331 (PTH1 receptor)>,
#   <Target 332 (PTH2 receptor)>,
#   <Target 333 (QRFP receptor)>,
#   <Target 2963 (Rhodopsin)>,
#   <Target 351 (RXFP1)>,
#   <Target 352 (RXFP2)>,
#   <Target 353 (RXFP3)>,
#   <Target 354 (RXFP4)>,
#   <Target 275 (S1P<sub>1</sub> receptor)>,
#   <Target 276 (S1P<sub>2</sub> receptor)>,
#   <Target 277 (S1P<sub>3</sub> receptor)>,
#   <Target 278 (S1P<sub>4</sub> receptor)>,
#   <Target 279 (S1P<sub>5</sub> receptor)>,
#   <Target 252 (secretin receptor)>,
#   <Target 239 (SMO)>,
#   <Target 355 (SST<sub>1</sub> receptor)>,
#   <Target 356 (SST<sub>2</sub> receptor)>,
#   <Target 357 (SST<sub>3</sub> receptor)>,
#   <Target 358 (SST<sub>4</sub> receptor)>,
#   <Target 359 (SST<sub>5</sub> receptor)>,
#   <Target 166 (succinate receptor)>,
#   <Target 364 (TA<sub>1</sub> receptor)>,
#   <Target 346 (TP receptor)>,
#   <Target 363 (TRH<sub>1</sub> receptor)>,
#   <Target 754 (TRH<sub>2</sub> receptor)>,
#   <Target 255 (TSH receptor)>,
#   <Target 365 (UT receptor)>,
#   <Target 371 (VPAC<sub>1</sub> receptor)>,
#   <Target 372 (VPAC<sub>2</sub> receptor)>,
#   <Target 366 (V<sub>1A</sub> receptor)>,
#   <Target 367 (V<sub>1B</sub> receptor)>,
#   <Target 368 (V<sub>2</sub> receptor)>,
#   <Target 75 (XCR1)>,
#   <Target 305 (Y<sub>1</sub> receptor)>,
#   <Target 306 (Y<sub>2</sub> receptor)>,
#   <Target 307 (Y<sub>4</sub> receptor)>,
#   <Target 308 (Y<sub>5</sub> receptor)>,
#   <Target 683 (y<sub>6</sub> receptor)>])

# %%
targets[0].database_links()
# Out:
# [<ChEMBL Target link (CHEMBL214) for Human>,
#  <ChEMBL Target link (CHEMBL3737) for Mouse>,
#  <ChEMBL Target link (CHEMBL273) for Rat>,
#  <DrugBank Target link (P08908) for Human>,
#  <Ensembl Gene link (ENSG00000178394) for Human>,
#  <Ensembl Gene link (ENSMUSG00000021721) for Mouse>,
#  <Ensembl Gene link (ENSRNOG00000010254) for Rat>,
#  <Entrez Gene link (3350) for Human>,
#  <Entrez Gene link (15550) for Mouse>,
#  <Entrez Gene link (24473) for Rat>,
#  <GPCRDB link (5ht1a_human) for Human>,
#  <GPCRDB link (5ht1a_mouse) for Mouse>,
#  <GPCRDB link (5ht1a_rat) for Rat>,
#  <OMIM link (109760) for Human>,
#  <Protein GI link (55956923) for Human>,
#  <Protein GI link (31542972) for Mouse>,
#  <Protein GI link (6981054) for Rat>,
#  <RefSeq Nucleotide link (NM_000524) for Human>,
#  <RefSeq Nucleotide link (NM_008308) for Mouse>,
#  <RefSeq Nucleotide link (NM_012585) for Rat>,
#  <RefSeq Protein link (NP_000515) for Human>,
#  <RefSeq Protein link (NP_032334) for Mouse>,
#  <RefSeq Protein link (NP_036717) for Rat>,
#  <UniProtKB link (P08908) for Human>,
#  <UniProtKB link (Q64264) for Mouse>,
#  <UniProtKB link (P19327) for Rat>,
#  <UniProtKB ID/Entry name link (5HT1A_HUMAN) for Human>,
#  <UniProtKB ID/Entry name link (5HT1A_MOUSE) for Mouse>,
#  <UniProtKB ID/Entry name link (5HT1A_RAT) for Rat>]

# %%
target_interactions = {}
for target in targets:
    interactions = target.interactions(species="human")
    if len(interactions) > 2:
        target_interactions[target.target_id()] = {"target": target,
                                                  "interactions": interactions
                                                 }

# %%
target_interactions
# Out:
# {1: {'target': <Target 1 (5-HT<sub>1A</sub> receptor)>,
#   'interactions': [<Interaction (3252 --> Human 1)>,
#    <Interaction (34 --> Human 1)>,
#    <Interaction (104 --> Human 1)>,
#    <Interaction (1 --> Human 1)>,
#    <Interaction (77 --> Human 1)>,
#    <Interaction (2 --> Human 1)>,
#    <Interaction (3227 --> Human 1)>,
#    <Interaction (78 --> Human 1)>,
#    <Interaction (79 --> Human 1)>,
#    <Interaction (67 --> Human 1)>,
#    <Interaction (3218 --> Human 1)>,
#    <Interaction (3251 --> Human 1)>,
#    <Interaction (31 --> Human 1)>,
#    <Interaction (3925 --> Human 1)>,
#    <Interaction (61 --> Human 1)>,
#    <Interaction (84 --> Human 1)>,
#    <Interaction (7191 --> Human 1)>,
#    <Interaction (36 --> Human 1)>,
#    <Interaction (7427 --> Human 1)>,
#    <Interaction (7427 --> Human 1)>,
#    <Interaction (52 --> Human 1)>,
#    <Interaction (53 --> Human 1)>,
#    <Interaction (54 --> Human 1)>,
#    <Interaction (55 --> Human 1)>,
#    <Interaction (56 --> Human 1)>,
#    <Interaction (57 --> Human 1)>,
#    <Interaction (58 --> Human 1)>,
#    <Interaction (59 --> Human 1)>,
#    <Interaction (8182 --> Human 1)>,
#    <Interaction (60 --> Human 1)>,
#    <Interaction (8434 --> Human 1)>,
#    <Interaction (8435 --> Human 1)>,
#    <Interaction (8436 --> Human 1)>,
#    <Interaction (62 --> Human 1)>,
#    <Interaction (7227 --> Human 1)>,
#    <Interaction (63 --> Human 1)>,
#    <Interaction (64 --> Human 1)>,
#    <Interaction (65 --> Human 1)>,
#    <Interaction (66 --> Human 1)>,
#    <Interaction (68 --> Human 1)>,
#    <Interaction (69 --> Human 1)>,
#    <Interaction (82 --> Human 1)>,
#    <Interaction (70 --> Human 1)>,
#    <Interaction (71 --> Human 1)>,
#    <Interaction (3 --> Human 1)>,
#    <Interaction (73 --> Human 1)>,
#    <Interaction (4 --> Human 1)>,
#    <Interaction (74 --> Human 1)>,
#    <Interaction (5 --> Human 1)>,
#    <Interaction (6 --> Human 1)>,
#    <Interaction (10454 --> Human 1)>,
#    <Interaction (8 --> Human 1)>,
#    <Interaction (75 --> Human 1)>,
#    <Interaction (76 --> Human 1)>,
#    <Interaction (87 --> Human 1)>,
#    <Interaction (88 --> Human 1)>,
#    <Interaction (44 --> Human 1)>,
#    <Interaction (9 --> Human 1)>,
#    <Interaction (10 --> Human 1)>,
#    <Interaction (11 --> Human 1)>,
#    <Interaction (12 --> Human 1)>,
#    <Interaction (13 --> Human 1)>,
#    <Interaction (14 --> Human 1)>,
#    <Interaction (15 --> Human 1)>,
#    <Interaction (16 --> Human 1)>,
#    <Interaction (17 --> Human 1)>,
#    <Interaction (18 --> Human 1)>,
#    <Interaction (19 --> Human 1)>,
#    <Interaction (20 --> Human 1)>,
#    <Interaction (21 --> Human 1)>,
#    <Interaction (22 --> Human 1)>,
#    <Interaction (23 --> Human 1)>,
#    <Interaction (24 --> Human 1)>,
#    <Interaction (25 --> Human 1)>,
#    <Interaction (26 --> Human 1)>,
#    <Interaction (28 --> Human 1)>,
#    <Interaction (29 --> Human 1)>,
#    <Interaction (32 --> Human 1)>,
#    <Interaction (35 --> Human 1)>,
#    <Interaction (37 --> Human 1)>,
#    <Interaction (38 --> Human 1)>,
#    <Interaction (39 --> Human 1)>,
#    <Interaction (40 --> Human 1)>,
#    <Interaction (41 --> Human 1)>,
#    <Interaction (42 --> Human 1)>,
#    <Interaction (43 --> Human 1)>,
#    <Interaction (45 --> Human 1)>,
#    <Interaction (46 --> Human 1)>,
#    <Interaction (47 --> Human 1)>,
#    <Interaction (48 --> Human 1)>,
#    <Interaction (49 --> Human 1)>,
#    <Interaction (50 --> Human 1)>,
#    <Interaction (51 --> Human 1)>,
#    <Interaction (30 --> Human 1)>,
#    <Interaction (83 --> Human 1)>,
#    <Interaction (85 --> Human 1)>,
#    <Interaction (86 --> Human 1)>,
#    <Interaction (89 --> Human 1)>,
#    <Interaction (90 --> Human 1)>,
#    <Interaction (91 --> Human 1)>,
#    <Interaction (92 --> Human 1)>,
#    <Interaction (93 --> Human 1)>,
#    <Interaction (94 --> Human 1)>,
#    <Interaction (95 --> Human 1)>,
#    <Interaction (96 --> Human 1)>,
#    <Interaction (97 --> Human 1)>,
#    <Interaction (98 --> Human 1)>,
#    <Interaction (99 --> Human 1)>,
#    <Interaction (100 --> Human 1)>,
#    <Interaction (101 --> Human 1)>,
#    <Interaction (102 --> Human 1)>,
#    <Interaction (103 --> Human 1)>,
#    <Interaction (81 --> Human 1)>,
#    <Interaction (72 --> Human 1)>,
#    <Interaction (80 --> Human 1)>,
#    <Interaction (167 --> Human 1)>,
#    <Interaction (33 --> Human 1)>,
#    <Interaction (7 --> Human 1)>,
#    <Interaction (3924 --> Human 1)>,
#    <Interaction (7351 --> Human 1)>]},
#  2: {'target': <Target 2 (5-HT<sub>1B</sub> receptor)>,
#   'interactions': [<Interaction (15 --> Human 2)>,
#    <Interaction (5 --> Human 2)>,
#    <Interaction (119 --> Human 2)>,
#    <Interaction (113 --> Human 2)>,
#    <Interaction (96 --> Human 2)>,
#    <Interaction (54 --> Human 2)>,
#    <Interaction (117 --> Human 2)>,
#    <Interaction (60 --> Human 2)>,
#    <Interaction (31 --> Human 2)>,
#    <Interaction (3926 --> Human 2)>,
#    <Interaction (118 --> Human 2)>,
#    <Interaction (3219 --> Human 2)>,
#    <Interaction (5 --> Human 2)>,
#    <Interaction (45 --> Human 2)>,
#    <Interaction (40 --> Human 2)>,
#    <Interaction (51 --> Human 2)>,
#    <Interaction (7191 --> Human 2)>,
#    <Interaction (10446 --> Human 2)>,
#    <Interaction (7110 --> Human 2)>,
#    <Interaction (65 --> Human 2)>,
#    <Interaction (66 --> Human 2)>,
#    <Interaction (67 --> Human 2)>,
#    <Interaction (3 --> Human 2)>,
#    <Interaction (106 --> Human 2)>,
#    <Interaction (4 --> Human 2)>,
#    <Interaction (107 --> Human 2)>,
#    <Interaction (6 --> Human 2)>,
#    <Interaction (108 --> Human 2)>,
#    <Interaction (10 --> Human 2)>,
#    <Interaction (109 --> Human 2)>,
#    <Interaction (110 --> Human 2)>,
#    <Interaction (16 --> Human 2)>,
#    <Interaction (114 --> Human 2)>,
#    <Interaction (21 --> Human 2)>,
#    <Interaction (22 --> Human 2)>,
#    <Interaction (23 --> Human 2)>,
#    <Interaction (28 --> Human 2)>,
#    <Interaction (29 --> Human 2)>,
#    <Interaction (115 --> Human 2)>,
#    <Interaction (120 --> Human 2)>,
#    <Interaction (34 --> Human 2)>,
#    <Interaction (35 --> Human 2)>,
#    <Interaction (37 --> Human 2)>,
#    <Interaction (38 --> Human 2)>,
#    <Interaction (121 --> Human 2)>,
#    <Interaction (122 --> Human 2)>,
#    <Interaction (43 --> Human 2)>,
#    <Interaction (123 --> Human 2)>,
#    <Interaction (47 --> Human 2)>,
#    <Interaction (124 --> Human 2)>,
#    <Interaction (48 --> Human 2)>,
#    <Interaction (52 --> Human 2)>,
#    <Interaction (56 --> Human 2)>,
#    <Interaction (125 --> Human 2)>,
#    <Interaction (57 --> Human 2)>,
#    <Interaction (59 --> Human 2)>,
#    <Interaction (126 --> Human 2)>,
#    <Interaction (14 --> Human 2)>,
#    <Interaction (129 --> Human 2)>,
#    <Interaction (75 --> Human 2)>,
#    <Interaction (76 --> Human 2)>,
#    <Interaction (77 --> Human 2)>,
#    <Interaction (88 --> Human 2)>,
#    <Interaction (133 --> Human 2)>,
#    <Interaction (89 --> Human 2)>,
#    <Interaction (134 --> Human 2)>,
#    <Interaction (46 --> Human 2)>,
#    <Interaction (92 --> Human 2)>,
#    <Interaction (136 --> Human 2)>,
#    <Interaction (97 --> Human 2)>,
#    <Interaction (98 --> Human 2)>,
#    <Interaction (102 --> Human 2)>,
#    <Interaction (103 --> Human 2)>,
#    <Interaction (137 --> Human 2)>,
#    <Interaction (7 --> Human 2)>,
#    <Interaction (39 --> Human 2)>,
#    <Interaction (14 --> Human 2)>,
#    <Interaction (218 --> Human 2)>,
#    <Interaction (113 --> Human 2)>,
#    <Interaction (3221 --> Human 2)>,
#    <Interaction (3231 --> Human 2)>,
#    <Interaction (131 --> Human 2)>,
#    <Interaction (7351 --> Human 2)>,
#    <Interaction (130 --> Human 2)>]},
#  3: {'target': <Target 3 (5-HT<sub>1D</sub> receptor)>,
#   'interactions': [<Interaction (119 --> Human 3)>,
#    <Interaction (118 --> Human 3)>,
#    <Interaction (34 --> Human 3)>,
#    <Interaction (60 --> Human 3)>,
#    <Interaction (51 --> Human 3)>,
#    <Interaction (10 --> Human 3)>,
#    <Interaction (96 --> Human 3)>,
#    <Interaction (54 --> Human 3)>,
#    <Interaction (15 --> Human 3)>,
#    <Interaction (117 --> Human 3)>,
#    <Interaction (121 --> Human 3)>,
#    <Interaction (149 --> Human 3)>,
#    <Interaction (7191 --> Human 3)>,
#    <Interaction (45 --> Human 3)>,
#    <Interaction (10446 --> Human 3)>,
#    <Interaction (7110 --> Human 3)>,
#    <Interaction (131 --> Human 3)>,
#    <Interaction (139 --> Human 3)>,
#    <Interaction (3 --> Human 3)>,
#    <Interaction (4 --> Human 3)>,
#    <Interaction (5 --> Human 3)>,
#    <Interaction (107 --> Human 3)>,
#    <Interaction (6 --> Human 3)>,
#    <Interaction (7 --> Human 3)>,
#    <Interaction (109 --> Human 3)>,
#    <Interaction (110 --> Human 3)>,
#    <Interaction (12 --> Human 3)>,
#    <Interaction (21 --> Human 3)>,
#    <Interaction (22 --> Human 3)>,
#    <Interaction (23 --> Human 3)>,
#    <Interaction (28 --> Human 3)>,
#    <Interaction (29 --> Human 3)>,
#    <Interaction (115 --> Human 3)>,
#    <Interaction (120 --> Human 3)>,
#    <Interaction (35 --> Human 3)>,
#    <Interaction (37 --> Human 3)>,
#    <Interaction (38 --> Human 3)>,
#    <Interaction (31 --> Human 3)>,
#    <Interaction (39 --> Human 3)>,
#    <Interaction (43 --> Human 3)>,
#    <Interaction (123 --> Human 3)>,
#    <Interaction (47 --> Human 3)>,
#    <Interaction (124 --> Human 3)>,
#    <Interaction (48 --> Human 3)>,
#    <Interaction (50 --> Human 3)>,
#    <Interaction (52 --> Human 3)>,
#    <Interaction (56 --> Human 3)>,
#    <Interaction (125 --> Human 3)>,
#    <Interaction (57 --> Human 3)>,
#    <Interaction (59 --> Human 3)>,
#    <Interaction (126 --> Human 3)>,
#    <Interaction (67 --> Human 3)>,
#    <Interaction (142 --> Human 3)>,
#    <Interaction (14 --> Human 3)>,
#    <Interaction (16 --> Human 3)>,
#    <Interaction (71 --> Human 3)>,
#    <Interaction (129 --> Human 3)>,
#    <Interaction (130 --> Human 3)>,
#    <Interaction (75 --> Human 3)>,
#    <Interaction (143 --> Human 3)>,
#    <Interaction (76 --> Human 3)>,
#    <Interaction (144 --> Human 3)>,
#    <Interaction (132 --> Human 3)>,
#    <Interaction (85 --> Human 3)>,
#    <Interaction (86 --> Human 3)>,
#    <Interaction (88 --> Human 3)>,
#    <Interaction (133 --> Human 3)>,
#    <Interaction (89 --> Human 3)>,
#    <Interaction (134 --> Human 3)>,
#    <Interaction (46 --> Human 3)>,
#    <Interaction (92 --> Human 3)>,
#    <Interaction (136 --> Human 3)>,
#    <Interaction (97 --> Human 3)>,
#    <Interaction (98 --> Human 3)>,
#    <Interaction (99 --> Human 3)>,
#    <Interaction (102 --> Human 3)>,
#    <Interaction (103 --> Human 3)>,
#    <Interaction (137 --> Human 3)>,
#    <Interaction (141 --> Human 3)>,
#    <Interaction (122 --> Human 3)>,
#    <Interaction (14 --> Human 3)>,
#    <Interaction (218 --> Human 3)>,
#    <Interaction (152 --> Human 3)>,
#    <Interaction (3248 --> Human 3)>,
#    <Interaction (262 --> Human 3)>,
#    <Interaction (40 --> Human 3)>,
#    <Interaction (77 --> Human 3)>]},
#  4: {'target': <Target 4 (5-ht<sub>1e</sub> receptor)>,
#   'interactions': [<Interaction (125 --> Human 4)>,
#    <Interaction (45 --> Human 4)>,
#    <Interaction (3927 --> Human 4)>,
#    <Interaction (123 --> Human 4)>,
#    <Interaction (8422 --> Human 4)>,
#    <Interaction (3248 --> Human 4)>,
#    <Interaction (4 --> Human 4)>,
#    <Interaction (5 --> Human 4)>,
#    <Interaction (145 --> Human 4)>,
#    <Interaction (107 --> Human 4)>,
#    <Interaction (146 --> Human 4)>,
#    <Interaction (7 --> Human 4)>,
#    <Interaction (142 --> Human 4)>,
#    <Interaction (10 --> Human 4)>,
#    <Interaction (147 --> Human 4)>,
#    <Interaction (12 --> Human 4)>,
#    <Interaction (14 --> Human 4)>,
#    <Interaction (21 --> Human 4)>,
#    <Interaction (22 --> Human 4)>,
#    <Interaction (115 --> Human 4)>,
#    <Interaction (38 --> Human 4)>,
#    <Interaction (121 --> Human 4)>,
#    <Interaction (39 --> Human 4)>,
#    <Interaction (40 --> Human 4)>,
#    <Interaction (148 --> Human 4)>,
#    <Interaction (149 --> Human 4)>,
#    <Interaction (47 --> Human 4)>,
#    <Interaction (50 --> Human 4)>,
#    <Interaction (51 --> Human 4)>,
#    <Interaction (54 --> Human 4)>,
#    <Interaction (57 --> Human 4)>,
#    <Interaction (59 --> Human 4)>,
#    <Interaction (60 --> Human 4)>,
#    <Interaction (3 --> Human 4)>,
#    <Interaction (67 --> Human 4)>,
#    <Interaction (85 --> Human 4)>,
#    <Interaction (133 --> Human 4)>,
#    <Interaction (89 --> Human 4)>,
#    <Interaction (150 --> Human 4)>,
#    <Interaction (134 --> Human 4)>,
#    <Interaction (136 --> Human 4)>,
#    <Interaction (96 --> Human 4)>,
#    <Interaction (98 --> Human 4)>,
#    <Interaction (102 --> Human 4)>,
#    <Interaction (103 --> Human 4)>,
#    <Interaction (218 --> Human 4)>,
#    <Interaction (152 --> Human 4)>]},
#  5: {'target': <Target 5 (5-HT<sub>1F</sub> receptor)>,
#   'interactions': [<Interaction (5 --> Human 5)>,
#    <Interaction (54 --> Human 5)>,
#    <Interaction (54 --> Human 5)>,
#    <Interaction (3927 --> Human 5)>,
#    <Interaction (151 --> Human 5)>,
#    <Interaction (40 --> Human 5)>,
#    <Interaction (21 --> Human 5)>,
#    <Interaction (4 --> Human 5)>,
#    <Interaction (5 --> Human 5)>,
#    <Interaction (145 --> Human 5)>,
#    <Interaction (107 --> Human 5)>,
#    <Interaction (7 --> Human 5)>,
#    <Interaction (10 --> Human 5)>,
#    <Interaction (147 --> Human 5)>,
#    <Interaction (14 --> Human 5)>,
#    <Interaction (73 --> Human 5)>,
#    <Interaction (115 --> Human 5)>,
#    <Interaction (38 --> Human 5)>,
#    <Interaction (121 --> Human 5)>,
#    <Interaction (122 --> Human 5)>,
#    <Interaction (39 --> Human 5)>,
#    <Interaction (149 --> Human 5)>,
#    <Interaction (45 --> Human 5)>,
#    <Interaction (47 --> Human 5)>,
#    <Interaction (50 --> Human 5)>,
#    <Interaction (51 --> Human 5)>,
#    <Interaction (125 --> Human 5)>,
#    <Interaction (57 --> Human 5)>,
#    <Interaction (60 --> Human 5)>,
#    <Interaction (3 --> Human 5)>,
#    <Interaction (133 --> Human 5)>,
#    <Interaction (89 --> Human 5)>,
#    <Interaction (150 --> Human 5)>,
#    <Interaction (134 --> Human 5)>,
#    <Interaction (96 --> Human 5)>,
#    <Interaction (98 --> Human 5)>,
#    <Interaction (102 --> Human 5)>,
#    <Interaction (20 --> Human 5)>,
#    <Interaction (218 --> Human 5)>,
#    <Interaction (152 --> Human 5)>,
#    <Interaction (3928 --> Human 5)>,
#    <Interaction (8422 --> Human 5)>]},
#  6: {'target': <Target 6 (5-HT<sub>2A</sub> receptor)>,
#   'interactions': [<Interaction (103 --> Human 6)>,
#    <Interaction (3242 --> Human 6)>,
#    <Interaction (147 --> Human 6)>,
#    <Interaction (22 --> Human 6)>,
#    <Interaction (34 --> Human 6)>,
#    <Interaction (96 --> Human 6)>,
#    <Interaction (212 --> Human 6)>,
#    <Interaction (98 --> Human 6)>,
#    <Interaction (135 --> Human 6)>,
#    <Interaction (83 --> Human 6)>,
#    <Interaction (205 --> Human 6)>,
#    <Interaction (214 --> Human 6)>,
#    <Interaction (213 --> Human 6)>,
#    <Interaction (86 --> Human 6)>,
#    <Interaction (207 --> Human 6)>,
#    <Interaction (3249 --> Human 6)>,
#    <Interaction (2 --> Human 6)>,
#    <Interaction (38 --> Human 6)>,
#    <Interaction (100 --> Human 6)>,
#    <Interaction (90 --> Human 6)>,
#    <Interaction (7227 --> Human 6)>,
#    <Interaction (7247 --> Human 6)>,
#    <Interaction (7241 --> Human 6)>,
#    <Interaction (59 --> Human 6)>,
#    <Interaction (7670 --> Human 6)>,
#    <Interaction (47 --> Human 6)>,
#    <Interaction (8182 --> Human 6)>,
#    <Interaction (8424 --> Human 6)>,
#    <Interaction (8427 --> Human 6)>,
#    <Interaction (8430 --> Human 6)>,
#    <Interaction (8434 --> Human 6)>,
#    <Interaction (8435 --> Human 6)>,
#    <Interaction (9099 --> Human 6)>,
#    <Interaction (9880 --> Human 6)>,
#    <Interaction (50 --> Human 6)>,
#    <Interaction (11291 --> Human 6)>,
#    <Interaction (185 --> Human 6)>,
#    <Interaction (197 --> Human 6)>,
#    <Interaction (5 --> Human 6)>,
#    <Interaction (157 --> Human 6)>,
#    <Interaction (152 --> Human 6)>,
#    <Interaction (153 --> Human 6)>,
#    <Interaction (154 --> Human 6)>,
#    <Interaction (155 --> Human 6)>,
#    <Interaction (157 --> Human 6)>,
#    <Interaction (4 --> Human 6)>,
#    <Interaction (107 --> Human 6)>,
#    <Interaction (158 --> Human 6)>,
#    <Interaction (159 --> Human 6)>,
#    <Interaction (142 --> Human 6)>,
#    <Interaction (160 --> Human 6)>,
#    <Interaction (10 --> Human 6)>,
#    <Interaction (161 --> Human 6)>,
#    <Interaction (163 --> Human 6)>,
#    <Interaction (14 --> Human 6)>,
#    <Interaction (17 --> Human 6)>,
#    <Interaction (21 --> Human 6)>,
#    <Interaction (165 --> Human 6)>,
#    <Interaction (5 --> Human 6)>,
#    <Interaction (23 --> Human 6)>,
#    <Interaction (166 --> Human 6)>,
#    <Interaction (167 --> Human 6)>,
#    <Interaction (28 --> Human 6)>,
#    <Interaction (29 --> Human 6)>,
#    <Interaction (115 --> Human 6)>,
#    <Interaction (168 --> Human 6)>,
#    <Interaction (35 --> Human 6)>,
#    <Interaction (37 --> Human 6)>,
#    <Interaction (39 --> Human 6)>,
#    <Interaction (149 --> Human 6)>,
#    <Interaction (43 --> Human 6)>,
#    <Interaction (150 --> Human 6)>,
#    <Interaction (170 --> Human 6)>,
#    <Interaction (171 --> Human 6)>,
#    <Interaction (48 --> Human 6)>,
#    <Interaction (91 --> Human 6)>,
#    <Interaction (50 --> Human 6)>,
#    <Interaction (173 --> Human 6)>,
#    <Interaction (56 --> Human 6)>,
#    <Interaction (125 --> Human 6)>,
#    <Interaction (62 --> Human 6)>,
#    <Interaction (67 --> Human 6)>,
#    <Interaction (174 --> Human 6)>,
#    <Interaction (175 --> Human 6)>,
#    <Interaction (176 --> Human 6)>,
#    <Interaction (177 --> Human 6)>,
#    <Interaction (178 --> Human 6)>,
#    <Interaction (180 --> Human 6)>,
#    <Interaction (181 --> Human 6)>,
#    <Interaction (182 --> Human 6)>,
#    <Interaction (183 --> Human 6)>,
#    <Interaction (184 --> Human 6)>,
#    <Interaction (186 --> Human 6)>,
#    <Interaction (187 --> Human 6)>,
#    <Interaction (189 --> Human 6)>,
#    <Interaction (190 --> Human 6)>,
#    <Interaction (191 --> Human 6)>,
#    <Interaction (130 --> Human 6)>,
#    <Interaction (192 --> Human 6)>,
#    <Interaction (193 --> Human 6)>,
#    <Interaction (194 --> Human 6)>,
#    <Interaction (195 --> Human 6)>,
#    <Interaction (198 --> Human 6)>,
#    <Interaction (199 --> Human 6)>,
#    <Interaction (33 --> Human 6)>,
#    <Interaction (144 --> Human 6)>,
#    <Interaction (84 --> Human 6)>,
#    <Interaction (202 --> Human 6)>,
#    <Interaction (204 --> Human 6)>,
#    <Interaction (85 --> Human 6)>,
#    <Interaction (206 --> Human 6)>,
#    <Interaction (133 --> Human 6)>,
#    <Interaction (89 --> Human 6)>,
#    <Interaction (134 --> Human 6)>,
#    <Interaction (209 --> Human 6)>,
#    <Interaction (91 --> Human 6)>,
#    <Interaction (92 --> Human 6)>,
#    <Interaction (97 --> Human 6)>,
#    <Interaction (97 --> Human 6)>,
#    <Interaction (52 --> Human 6)>,
#    <Interaction (210 --> Human 6)>,
#    <Interaction (211 --> Human 6)>,
#    <Interaction (99 --> Human 6)>,
#    <Interaction (57 --> Human 6)>,
#    <Interaction (7 --> Human 6)>,
#    <Interaction (188 --> Human 6)>,
#    <Interaction (129 --> Human 6)>,
#    <Interaction (109 --> Human 6)>,
#    <Interaction (2941 --> Human 6)>,
#    <Interaction (2941 --> Human 6)>,
#    <Interaction (88 --> Human 6)>,
#    <Interaction (7351 --> Human 6)>,
#    <Interaction (8423 --> Human 6)>,
#    <Interaction (9825 --> Human 6)>]},
#  7: {'target': <Target 7 (5-HT<sub>2B</sub> receptor)>,
#   'interactions': [<Interaction (152 --> Human 7)>,
#    <Interaction (216 --> Human 7)>,
#    <Interaction (33 --> Human 7)>,
#    <Interaction (232 --> Human 7)>,
#    <Interaction (169 --> Human 7)>,
#    <Interaction (2 --> Human 7)>,
#    <Interaction (134 --> Human 7)>,
#    <Interaction (135 --> Human 7)>,
#    <Interaction (190 --> Human 7)>,
#    <Interaction (282 --> Human 7)>,
#    <Interaction (17 --> Human 7)>,
#    <Interaction (8427 --> Human 7)>,
#    <Interaction (147 --> Human 7)>,
#    <Interaction (219 --> Human 7)>,
#    <Interaction (188 --> Human 7)>,
#    <Interaction (10615 --> Human 7)>,
#    <Interaction (161 --> Human 7)>,
#    <Interaction (157 --> Human 7)>,
#    <Interaction (215 --> Human 7)>,
#    <Interaction (153 --> Human 7)>,
#    <Interaction (154 --> Human 7)>,
#    <Interaction (157 --> Human 7)>,
#    <Interaction (4 --> Human 7)>,
#    <Interaction (5 --> Human 7)>,
#    <Interaction (7 --> Human 7)>,
#    <Interaction (142 --> Human 7)>,
#    <Interaction (160 --> Human 7)>,
#    <Interaction (10 --> Human 7)>,
#    <Interaction (163 --> Human 7)>,
#    <Interaction (14 --> Human 7)>,
#    <Interaction (21 --> Human 7)>,
#    <Interaction (165 --> Human 7)>,
#    <Interaction (23 --> Human 7)>,
#    <Interaction (167 --> Human 7)>,
#    <Interaction (28 --> Human 7)>,
#    <Interaction (29 --> Human 7)>,
#    <Interaction (115 --> Human 7)>,
#    <Interaction (168 --> Human 7)>,
#    <Interaction (225 --> Human 7)>,
#    <Interaction (37 --> Human 7)>,
#    <Interaction (149 --> Human 7)>,
#    <Interaction (150 --> Human 7)>,
#    <Interaction (170 --> Human 7)>,
#    <Interaction (171 --> Human 7)>,
#    <Interaction (48 --> Human 7)>,
#    <Interaction (91 --> Human 7)>,
#    <Interaction (173 --> Human 7)>,
#    <Interaction (125 --> Human 7)>,
#    <Interaction (3 --> Human 7)>,
#    <Interaction (175 --> Human 7)>,
#    <Interaction (177 --> Human 7)>,
#    <Interaction (183 --> Human 7)>,
#    <Interaction (185 --> Human 7)>,
#    <Interaction (186 --> Human 7)>,
#    <Interaction (187 --> Human 7)>,
#    <Interaction (129 --> Human 7)>,
#    <Interaction (221 --> Human 7)>,
#    <Interaction (189 --> Human 7)>,
#    <Interaction (191 --> Human 7)>,
#    <Interaction (130 --> Human 7)>,
#    <Interaction (192 --> Human 7)>,
#    <Interaction (193 --> Human 7)>,
#    <Interaction (194 --> Human 7)>,
#    <Interaction (143 --> Human 7)>,
#    <Interaction (195 --> Human 7)>,
#    <Interaction (223 --> Human 7)>,
#    <Interaction (198 --> Human 7)>,
#    <Interaction (176 --> Human 7)>,
#    <Interaction (166 --> Human 7)>,
#    <Interaction (35 --> Human 7)>,
#    <Interaction (38 --> Human 7)>,
#    <Interaction (203 --> Human 7)>,
#    <Interaction (86 --> Human 7)>,
#    <Interaction (88 --> Human 7)>,
#    <Interaction (43 --> Human 7)>,
#    <Interaction (224 --> Human 7)>,
#    <Interaction (206 --> Human 7)>,
#    <Interaction (133 --> Human 7)>,
#    <Interaction (89 --> Human 7)>,
#    <Interaction (208 --> Human 7)>,
#    <Interaction (225 --> Human 7)>,
#    <Interaction (91 --> Human 7)>,
#    <Interaction (49 --> Human 7)>,
#    <Interaction (136 --> Human 7)>,
#    <Interaction (97 --> Human 7)>,
#    <Interaction (52 --> Human 7)>,
#    <Interaction (210 --> Human 7)>,
#    <Interaction (99 --> Human 7)>,
#    <Interaction (53 --> Human 7)>,
#    <Interaction (226 --> Human 7)>,
#    <Interaction (56 --> Human 7)>,
#    <Interaction (213 --> Human 7)>,
#    <Interaction (57 --> Human 7)>,
#    <Interaction (102 --> Human 7)>,
#    <Interaction (217 --> Human 7)>,
#    <Interaction (109 --> Human 7)>,
#    <Interaction (2941 --> Human 7)>,
#    <Interaction (2941 --> Human 7)>,
#    <Interaction (8424 --> Human 7)>]},
#  8: {'target': <Target 8 (5-HT<sub>2C</sub> receptor)>,
#   'interactions': [<Interaction (34 --> Human 8)>,
#    <Interaction (166 --> Human 8)>,
#    <Interaction (134 --> Human 8)>,
#    <Interaction (100 --> Human 8)>,
#    <Interaction (98 --> Human 8)>,
#    <Interaction (135 --> Human 8)>,
#    <Interaction (205 --> Human 8)>,
#    <Interaction (47 --> Human 8)>,
#    <Interaction (213 --> Human 8)>,
#    <Interaction (198 --> Human 8)>,
#    <Interaction (219 --> Human 8)>,
#    <Interaction (147 --> Human 8)>,
#    <Interaction (2 --> Human 8)>,
#    <Interaction (59 --> Human 8)>,
#    <Interaction (7241 --> Human 8)>,
#    <Interaction (214 --> Human 8)>,
#    <Interaction (169 --> Human 8)>,
#    <Interaction (7227 --> Human 8)>,
#    <Interaction (8689 --> Human 8)>,
#    <Interaction (232 --> Human 8)>,
#    <Interaction (43 --> Human 8)>,
#    <Interaction (157 --> Human 8)>,
#    <Interaction (28 --> Human 8)>,
#    <Interaction (152 --> Human 8)>,
#    <Interaction (153 --> Human 8)>,
#    <Interaction (154 --> Human 8)>,
#    <Interaction (157 --> Human 8)>,
#    <Interaction (4 --> Human 8)>,
#    <Interaction (145 --> Human 8)>,
#    <Interaction (107 --> Human 8)>,
#    <Interaction (7 --> Human 8)>,
#    <Interaction (142 --> Human 8)>,
#    <Interaction (160 --> Human 8)>,
#    <Interaction (10 --> Human 8)>,
#    <Interaction (163 --> Human 8)>,
#    <Interaction (14 --> Human 8)>,
#    <Interaction (17 --> Human 8)>,
#    <Interaction (21 --> Human 8)>,
#    <Interaction (165 --> Human 8)>,
#    <Interaction (23 --> Human 8)>,
#    <Interaction (167 --> Human 8)>,
#    <Interaction (29 --> Human 8)>,
#    <Interaction (115 --> Human 8)>,
#    <Interaction (168 --> Human 8)>,
#    <Interaction (230 --> Human 8)>,
#    <Interaction (35 --> Human 8)>,
#    <Interaction (37 --> Human 8)>,
#    <Interaction (149 --> Human 8)>,
#    <Interaction (170 --> Human 8)>,
#    <Interaction (171 --> Human 8)>,
#    <Interaction (124 --> Human 8)>,
#    <Interaction (48 --> Human 8)>,
#    <Interaction (173 --> Human 8)>,
#    <Interaction (125 --> Human 8)>,
#    <Interaction (174 --> Human 8)>,
#    <Interaction (175 --> Human 8)>,
#    <Interaction (176 --> Human 8)>,
#    <Interaction (231 --> Human 8)>,
#    <Interaction (185 --> Human 8)>,
#    <Interaction (186 --> Human 8)>,
#    <Interaction (188 --> Human 8)>,
#    <Interaction (129 --> Human 8)>,
#    <Interaction (221 --> Human 8)>,
#    <Interaction (189 --> Human 8)>,
#    <Interaction (190 --> Human 8)>,
#    <Interaction (191 --> Human 8)>,
#    <Interaction (130 --> Human 8)>,
#    <Interaction (130 --> Human 8)>,
#    <Interaction (192 --> Human 8)>,
#    <Interaction (194 --> Human 8)>,
#    <Interaction (195 --> Human 8)>,
#    <Interaction (33 --> Human 8)>,
#    <Interaction (83 --> Human 8)>,
#    <Interaction (38 --> Human 8)>,
#    <Interaction (84 --> Human 8)>,
#    <Interaction (202 --> Human 8)>,
#    <Interaction (88 --> Human 8)>,
#    <Interaction (206 --> Human 8)>,
#    <Interaction (133 --> Human 8)>,
#    <Interaction (89 --> Human 8)>,
#    <Interaction (209 --> Human 8)>,
#    <Interaction (96 --> Human 8)>,
#    <Interaction (97 --> Human 8)>,
#    <Interaction (52 --> Human 8)>,
#    <Interaction (210 --> Human 8)>,
#    <Interaction (99 --> Human 8)>,
#    <Interaction (56 --> Human 8)>,
#    <Interaction (101 --> Human 8)>,
#    <Interaction (57 --> Human 8)>,
#    <Interaction (103 --> Human 8)>,
#    <Interaction (193 --> Human 8)>,
#    <Interaction (150 --> Human 8)>,
#    <Interaction (109 --> Human 8)>,
#    <Interaction (161 --> Human 8)>,
#    <Interaction (5 --> Human 8)>,
#    <Interaction (2941 --> Human 8)>,
#    <Interaction (2941 --> Human 8)>,
#    <Interaction (229 --> Human 8)>,
#    <Interaction (187 --> Human 8)>,
#    <Interaction (3223 --> Human 8)>,
#    <Interaction (2941 --> Human 8)>]},
#  9: {'target': <Target 9 (5-HT<sub>4</sub> receptor)>,
#   'interactions': [<Interaction (5 --> Human 9)>,
#    <Interaction (240 --> Human 9)>,
#    <Interaction (3244 --> Human 9)>,
#    <Interaction (7427 --> Human 9)>,
#    <Interaction (9059 --> Human 9)>,
#    <Interaction (152 --> Human 9)>,
#    <Interaction (107 --> Human 9)>,
#    <Interaction (233 --> Human 9)>,
#    <Interaction (237 --> Human 9)>,
#    <Interaction (29 --> Human 9)>,
#    <Interaction (242 --> Human 9)>,
#    <Interaction (243 --> Human 9)>,
#    <Interaction (244 --> Human 9)>,
#    <Interaction (226 --> Human 9)>,
#    <Interaction (245 --> Human 9)>,
#    <Interaction (246 --> Human 9)>,
#    <Interaction (248 --> Human 9)>,
#    <Interaction (249 --> Human 9)>,
#    <Interaction (254 --> Human 9)>,
#    <Interaction (255 --> Human 9)>,
#    <Interaction (257 --> Human 9)>,
#    <Interaction (225 --> Human 9)>,
#    <Interaction (260 --> Human 9)>,
#    <Interaction (247 --> Human 9)>,
#    <Interaction (250 --> Human 9)>,
#    <Interaction (256 --> Human 9)>,
#    <Interaction (259 --> Human 9)>,
#    <Interaction (5 --> Human 9)>,
#    <Interaction (234 --> Human 9)>,
#    <Interaction (235 --> Human 9)>,
#    <Interaction (8425 --> Human 9)>,
#    <Interaction (8426 --> Human 9)>,
#    <Interaction (8427 --> Human 9)>]},
#  10: {'target': <Target 10 (5-HT<sub>5A</sub> receptor)>,
#   'interactions': [<Interaction (71 --> Human 10)>,
#    <Interaction (4 --> Human 10)>,
#    <Interaction (5 --> Human 10)>,
#    <Interaction (7 --> Human 10)>,
#    <Interaction (12 --> Human 10)>,
#    <Interaction (23 --> Human 10)>,
#    <Interaction (39 --> Human 10)>,
#    <Interaction (54 --> Human 10)>,
#    <Interaction (63 --> Human 10)>,
#    <Interaction (38 --> Human 10)>,
#    <Interaction (149 --> Human 10)>,
#    <Interaction (88 --> Human 10)>,
#    <Interaction (133 --> Human 10)>,
#    <Interaction (89 --> Human 10)>,
#    <Interaction (134 --> Human 10)>,
#    <Interaction (97 --> Human 10)>,
#    <Interaction (102 --> Human 10)>,
#    <Interaction (262 --> Human 10)>,
#    <Interaction (261 --> Human 10)>,
#    <Interaction (264 --> Human 10)>,
#    <Interaction (7351 --> Human 10)>]},
#  11: {'target': <Target 11 (5-HT<sub>6</sub> receptor)>,
#   'interactions': [<Interaction (3235 --> Human 11)>,
#    <Interaction (3246 --> Human 11)>,
#    <Interaction (262 --> Human 11)>,
#    <Interaction (201 --> Human 11)>,
#    <Interaction (3232 --> Human 11)>,
#    <Interaction (8430 --> Human 11)>,
#    <Interaction (9444 --> Human 11)>,
#    <Interaction (219 --> Human 11)>,
#    <Interaction (4 --> Human 11)>,
#    <Interaction (5 --> Human 11)>,
#    <Interaction (107 --> Human 11)>,
#    <Interaction (10 --> Human 11)>,
#    <Interaction (12 --> Human 11)>,
#    <Interaction (14 --> Human 11)>,
#    <Interaction (17 --> Human 11)>,
#    <Interaction (23 --> Human 11)>,
#    <Interaction (29 --> Human 11)>,
#    <Interaction (115 --> Human 11)>,
#    <Interaction (101 --> Human 11)>,
#    <Interaction (141 --> Human 11)>,
#    <Interaction (39 --> Human 11)>,
#    <Interaction (149 --> Human 11)>,
#    <Interaction (43 --> Human 11)>,
#    <Interaction (57 --> Human 11)>,
#    <Interaction (273 --> Human 11)>,
#    <Interaction (71 --> Human 11)>,
#    <Interaction (274 --> Human 11)>,
#    <Interaction (200 --> Human 11)>,
#    <Interaction (83 --> Human 11)>,
#    <Interaction (38 --> Human 11)>,
#    <Interaction (277 --> Human 11)>,
#    <Interaction (202 --> Human 11)>,
#    <Interaction (279 --> Human 11)>,
#    <Interaction (204 --> Human 11)>,
#    <Interaction (87 --> Human 11)>,
#    <Interaction (205 --> Human 11)>,
#    <Interaction (206 --> Human 11)>,
#    <Interaction (133 --> Human 11)>,
#    <Interaction (89 --> Human 11)>,
#    <Interaction (134 --> Human 11)>,
#    <Interaction (135 --> Human 11)>,
#    <Interaction (47 --> Human 11)>,
#    <Interaction (209 --> Human 11)>,
#    <Interaction (96 --> Human 11)>,
#    <Interaction (97 --> Human 11)>,
#    <Interaction (54 --> Human 11)>,
#    <Interaction (100 --> Human 11)>,
#    <Interaction (103 --> Human 11)>,
#    <Interaction (275 --> Human 11)>,
#    <Interaction (35 --> Human 11)>,
#    <Interaction (3240 --> Human 11)>,
#    <Interaction (3245 --> Human 11)>,
#    <Interaction (3217 --> Human 11)>,
#    <Interaction (276 --> Human 11)>,
#    <Interaction (3241 --> Human 11)>,
#    <Interaction (3235 --> Human 11)>,
#    <Interaction (7356 --> Human 11)>,
#    <Interaction (7351 --> Human 11)>,
#    <Interaction (8428 --> Human 11)>,
#    <Interaction (8429 --> Human 11)>,
#    <Interaction (8689 --> Human 11)>]},
#  12: {'target': <Target 12 (5-HT<sub>7</sub> receptor)>,
#   'interactions': [<Interaction (3248 --> Human 12)>,
#    <Interaction (7461 --> Human 12)>,
#    <Interaction (219 --> Human 12)>,
#    <Interaction (3233 --> Human 12)>,
#    <Interaction (154 --> Human 12)>,
#    <Interaction (3 --> Human 12)>,
#    <Interaction (4 --> Human 12)>,
#    <Interaction (5 --> Human 12)>,
#    <Interaction (107 --> Human 12)>,
#    <Interaction (7 --> Human 12)>,
#    <Interaction (12 --> Human 12)>,
#    <Interaction (21 --> Human 12)>,
#    <Interaction (29 --> Human 12)>,
#    <Interaction (122 --> Human 12)>,
#    <Interaction (125 --> Human 12)>,
#    <Interaction (57 --> Human 12)>,
#    <Interaction (71 --> Human 12)>,
#    <Interaction (257 --> Human 12)>,
#    <Interaction (83 --> Human 12)>,
#    <Interaction (38 --> Human 12)>,
#    <Interaction (84 --> Human 12)>,
#    <Interaction (277 --> Human 12)>,
#    <Interaction (121 --> Human 12)>,
#    <Interaction (279 --> Human 12)>,
#    <Interaction (204 --> Human 12)>,
#    <Interaction (86 --> Human 12)>,
#    <Interaction (87 --> Human 12)>,
#    <Interaction (88 --> Human 12)>,
#    <Interaction (206 --> Human 12)>,
#    <Interaction (133 --> Human 12)>,
#    <Interaction (89 --> Human 12)>,
#    <Interaction (134 --> Human 12)>,
#    <Interaction (135 --> Human 12)>,
#    <Interaction (47 --> Human 12)>,
#    <Interaction (209 --> Human 12)>,
#    <Interaction (283 --> Human 12)>,
#    <Interaction (96 --> Human 12)>,
#    <Interaction (97 --> Human 12)>,
#    <Interaction (99 --> Human 12)>,
#    <Interaction (54 --> Human 12)>,
#    <Interaction (100 --> Human 12)>,
#    <Interaction (102 --> Human 12)>,
#    <Interaction (59 --> Human 12)>,
#    <Interaction (103 --> Human 12)>,
#    <Interaction (284 --> Human 12)>,
#    <Interaction (3237 --> Human 12)>,
#    <Interaction (3247 --> Human 12)>,
#    <Interaction (262 --> Human 12)>,
#    <Interaction (281 --> Human 12)>,
#    <Interaction (3929 --> Human 12)>,
#    <Interaction (7351 --> Human 12)>,
#    <Interaction (8431 --> Human 12)>,
#    <Interaction (8432 --> Human 12)>,
#    <Interaction (8433 --> Human 12)>,
#    <Interaction (8434 --> Human 12)>,
#    <Interaction (8435 --> Human 12)>,
#    <Interaction (272 --> Human 12)>]},
#  80: {'target': <Target 80 (ACKR3)>,
#   'interactions': [<Interaction (836 --> Human 80)>,
#    <Interaction (844 --> Human 80)>,
#    <Interaction (2902 --> Human 80)>,
#    <Interaction (4358 --> Human 80)>]},
#  315: {'target': <Target 315 (ACKR4)>,
#   'interactions': [<Interaction (811 --> Human 315)>,
#    <Interaction (817 --> Human 315)>,
#    <Interaction (817 --> Human 315)>,
#    <Interaction (811 --> Human 315)>,
#    <Interaction (810 --> Human 315)>,
#    <Interaction (810 --> Human 315)>]},
#  25: {'target': <Target 25 (&alpha;<sub>2A</sub>-adrenoceptor)>,
#   'interactions': [<Interaction (4186 --> Human 25)>,
#    <Interaction (522 --> Human 25)>,
#    <Interaction (520 --> Human 25)>,
#    <Interaction (521 --> Human 25)>,
#    <Interaction (527 --> Human 25)>,
#    <Interaction (479 --> Human 25)>,
#    <Interaction (516 --> Human 25)>,
#    <Interaction (7117 --> Human 25)>,
#    <Interaction (7241 --> Human 25)>,
#    <Interaction (7241 --> Human 25)>,
#    <Interaction (5443 --> Human 25)>,
#    <Interaction (7310 --> Human 25)>,
#    <Interaction (7461 --> Human 25)>,
#    <Interaction (505 --> Human 25)>,
#    <Interaction (9868 --> Human 25)>,
#    <Interaction (320 --> Human 25)>,
#    <Interaction (313 --> Human 25)>,
#    <Interaction (499 --> Human 25)>,
#    <Interaction (33 --> Human 25)>,
#    <Interaction (48 --> Human 25)>,
#    <Interaction (523 --> Human 25)>,
#    <Interaction (524 --> Human 25)>,
#    <Interaction (526 --> Human 25)>,
#    <Interaction (528 --> Human 25)>,
#    <Interaction (223 --> Human 25)>,
#    <Interaction (35 --> Human 25)>,
#    <Interaction (37 --> Human 25)>,
#    <Interaction (83 --> Human 25)>,
#    <Interaction (43 --> Human 25)>,
#    <Interaction (502 --> Human 25)>,
#    <Interaction (49 --> Human 25)>,
#    <Interaction (503 --> Human 25)>,
#    <Interaction (136 --> Human 25)>,
#    <Interaction (53 --> Human 25)>,
#    <Interaction (56 --> Human 25)>,
#    <Interaction (102 --> Human 25)>,
#    <Interaction (124 --> Human 25)>,
#    <Interaction (525 --> Human 25)>,
#    <Interaction (1192 --> Human 25)>]},
#  26: {'target': <Target 26 (&alpha;<sub>2B</sub>-adrenoceptor)>,
#   'interactions': [<Interaction (516 --> Human 26)>,
#    <Interaction (522 --> Human 26)>,
#    <Interaction (520 --> Human 26)>,
#    <Interaction (521 --> Human 26)>,
#    <Interaction (527 --> Human 26)>,
#    <Interaction (505 --> Human 26)>,
#    <Interaction (509 --> Human 26)>,
#    <Interaction (7241 --> Human 26)>,
#    <Interaction (5443 --> Human 26)>,
#    <Interaction (7268 --> Human 26)>,
#    <Interaction (103 --> Human 26)>,
#    <Interaction (479 --> Human 26)>,
#    <Interaction (9868 --> Human 26)>,
#    <Interaction (124 --> Human 26)>,
#    <Interaction (48 --> Human 26)>,
#    <Interaction (523 --> Human 26)>,
#    <Interaction (525 --> Human 26)>,
#    <Interaction (526 --> Human 26)>,
#    <Interaction (499 --> Human 26)>,
#    <Interaction (528 --> Human 26)>,
#    <Interaction (223 --> Human 26)>,
#    <Interaction (33 --> Human 26)>,
#    <Interaction (35 --> Human 26)>,
#    <Interaction (37 --> Human 26)>,
#    <Interaction (83 --> Human 26)>,
#    <Interaction (43 --> Human 26)>,
#    <Interaction (502 --> Human 26)>,
#    <Interaction (136 --> Human 26)>,
#    <Interaction (52 --> Human 26)>,
#    <Interaction (53 --> Human 26)>,
#    <Interaction (56 --> Human 26)>,
#    <Interaction (503 --> Human 26)>,
#    <Interaction (524 --> Human 26)>,
#    <Interaction (7310 --> Human 26)>,
#    <Interaction (102 --> Human 26)>]},
#  27: {'target': <Target 27 (&alpha;<sub>2C</sub>-adrenoceptor)>,
#   'interactions': [<Interaction (505 --> Human 27)>,
#    <Interaction (527 --> Human 27)>,
#    <Interaction (124 --> Human 27)>,
#    <Interaction (499 --> Human 27)>,
#    <Interaction (521 --> Human 27)>,
#    <Interaction (53 --> Human 27)>,
#    <Interaction (509 --> Human 27)>,
#    <Interaction (522 --> Human 27)>,
#    <Interaction (520 --> Human 27)>,
#    <Interaction (7117 --> Human 27)>,
#    <Interaction (7241 --> Human 27)>,
#    <Interaction (5443 --> Human 27)>,
#    <Interaction (2741 --> Human 27)>,
#    <Interaction (7241 --> Human 27)>,
#    <Interaction (7461 --> Human 27)>,
#    <Interaction (479 --> Human 27)>,
#    <Interaction (9868 --> Human 27)>,
#    <Interaction (516 --> Human 27)>,
#    <Interaction (48 --> Human 27)>,
#    <Interaction (523 --> Human 27)>,
#    <Interaction (525 --> Human 27)>,
#    <Interaction (526 --> Human 27)>,
#    <Interaction (37 --> Human 27)>,
#    <Interaction (83 --> Human 27)>,
#    <Interaction (43 --> Human 27)>,
#    <Interaction (502 --> Human 27)>,
#    <Interaction (49 --> Human 27)>,
#    <Interaction (136 --> Human 27)>,
#    <Interaction (52 --> Human 27)>,
#    <Interaction (56 --> Human 27)>,
#    <Interaction (524 --> Human 27)>,
#    <Interaction (102 --> Human 27)>,
#    <Interaction (528 --> Human 27)>,
#    <Interaction (223 --> Human 27)>,
#    <Interaction (33 --> Human 27)>,
#    <Interaction (35 --> Human 27)>,
#    <Interaction (503 --> Human 27)>,
#    <Interaction (3930 --> Human 27)>,
#    <Interaction (7310 --> Human 27)>]},
#  49: {'target': <Target 49 (AM<sub>1</sub> receptor)>,
#   'interactions': [<Interaction (683 --> Human 49)>,
#    <Interaction (3768 --> Human 49)>,
#    <Interaction (684 --> Human 49)>,
#    <Interaction (681 --> Human 49)>,
#    <Interaction (682 --> Human 49)>,
#    <Interaction (700 --> Human 49)>,
#    <Interaction (706 --> Human 49)>]},
#  50: {'target': <Target 50 (AM<sub>2</sub> receptor)>,
#   'interactions': [<Interaction (706 --> Human 50)>,
#    <Interaction (684 --> Human 50)>,
#    <Interaction (3768 --> Human 50)>,
#    <Interaction (683 --> Human 50)>,
#    <Interaction (11148 --> Human 50)>,
#    <Interaction (681 --> Human 50)>,
#    <Interaction (682 --> Human 50)>,
#    <Interaction (700 --> Human 50)>,
#    <Interaction (706 --> Human 50)>]},
#  44: {'target': <Target 44 (AMY<sub>1</sub> receptor)>,
#   'interactions': [<Interaction (682 --> Human 44)>,
#    <Interaction (688 --> Human 44)>,
#    <Interaction (681 --> Human 44)>,
#    <Interaction (3770 --> Human 44)>,
#    <Interaction (700 --> Human 44)>,
#    <Interaction (684 --> Human 44)>,
#    <Interaction (687 --> Human 44)>,
#    <Interaction (3766 --> Human 44)>,
#    <Interaction (690 --> Human 44)>,
#    <Interaction (682 --> Human 44)>,
#    <Interaction (683 --> Human 44)>,
#    <Interaction (692 --> Human 44)>,
#    <Interaction (693 --> Human 44)>,
#    <Interaction (689 --> Human 44)>,
#    <Interaction (685 --> Human 44)>,
#    <Interaction (7482 --> Human 44)>,
#    <Interaction (702 --> Human 44)>]},
#  45: {'target': <Target 45 (AMY<sub>2</sub> receptor)>,
#   'interactions': [<Interaction (688 --> Human 45)>,
#    <Interaction (684 --> Human 45)>,
#    <Interaction (687 --> Human 45)>,
#    <Interaction (3770 --> Human 45)>,
#    <Interaction (7482 --> Human 45)>,
#    <Interaction (681 --> Human 45)>,
#    <Interaction (683 --> Human 45)>,
#    <Interaction (685 --> Human 45)>,
#    <Interaction (692 --> Human 45)>]},
#  46: {'target': <Target 46 (AMY<sub>3</sub> receptor)>,
#   'interactions': [<Interaction (684 --> Human 46)>,
#    <Interaction (688 --> Human 46)>,
#    <Interaction (700 --> Human 46)>,
#    <Interaction (683 --> Human 46)>,
#    <Interaction (687 --> Human 46)>,
#    <Interaction (3770 --> Human 46)>,
#    <Interaction (10660 --> Human 46)>,
#    <Interaction (10683 --> Human 46)>,
#    <Interaction (10684 --> Human 46)>,
#    <Interaction (681 --> Human 46)>,
#    <Interaction (682 --> Human 46)>,
#    <Interaction (685 --> Human 46)>,
#    <Interaction (689 --> Human 46)>,
#    <Interaction (690 --> Human 46)>,
#    <Interaction (7482 --> Human 46)>]},
#  36: {'target': <Target 36 (apelin receptor)>,
#   'interactions': [<Interaction (7801 --> Human 36)>,
#    <Interaction (6282 --> Human 36)>,
#    <Interaction (6313 --> Human 36)>,
#    <Interaction (6312 --> Human 36)>,
#    <Interaction (10061 --> Human 36)>,
#    <Interaction (6314 --> Human 36)>,
#    <Interaction (6311 --> Human 36)>,
#    <Interaction (601 --> Human 36)>,
#    <Interaction (604 --> Human 36)>,
#    <Interaction (602 --> Human 36)>,
#    <Interaction (3761 --> Human 36)>,
#    <Interaction (6186 --> Human 36)>,
#    <Interaction (6187 --> Human 36)>,
#    <Interaction (8524 --> Human 36)>,
#    <Interaction (8525 --> Human 36)>,
#    <Interaction (8526 --> Human 36)>,
#    <Interaction (605 --> Human 36)>,
#    <Interaction (599 --> Human 36)>,
#    <Interaction (603 --> Human 36)>,
#    <Interaction (10557 --> Human 36)>,
#    <Interaction (3556 --> Human 36)>,
#    <Interaction (607 --> Human 36)>,
#    <Interaction (606 --> Human 36)>,
#    <Interaction (7930 --> Human 36)>,
#    <Interaction (8523 --> Human 36)>,
#    <Interaction (9448 --> Human 36)>]},
#  18: {'target': <Target 18 (A<sub>1</sub> receptor)>,
#   'interactions': [<Interaction (373 --> Human 18)>,
#    <Interaction (4252 --> Human 18)>,
#    <Interaction (449 --> Human 18)>,
#    <Interaction (10235 --> Human 18)>,
#    <Interaction (5601 --> Human 18)>,
#    <Interaction (5620 --> Human 18)>,
#    <Interaction (375 --> Human 18)>,
#    <Interaction (405 --> Human 18)>,
#    <Interaction (403 --> Human 18)>,
#    <Interaction (390 --> Human 18)>,
#    <Interaction (379 --> Human 18)>,
#    <Interaction (422 --> Human 18)>,
#    <Interaction (414 --> Human 18)>,
#    <Interaction (377 --> Human 18)>,
#    <Interaction (5608 --> Human 18)>,
#    <Interaction (2844 --> Human 18)>,
#    <Interaction (457 --> Human 18)>,
#    <Interaction (3281 --> Human 18)>,
#    <Interaction (384 --> Human 18)>,
#    <Interaction (5603 --> Human 18)>,
#    <Interaction (5605 --> Human 18)>,
#    <Interaction (5606 --> Human 18)>,
#    <Interaction (5607 --> Human 18)>,
#    <Interaction (5610 --> Human 18)>,
#    <Interaction (5612 --> Human 18)>,
#    <Interaction (5613 --> Human 18)>,
#    <Interaction (5614 --> Human 18)>,
#    <Interaction (3283 --> Human 18)>,
#    <Interaction (5615 --> Human 18)>,
#    <Interaction (3286 --> Human 18)>,
#    <Interaction (459 --> Human 18)>,
#    <Interaction (5617 --> Human 18)>,
#    <Interaction (5618 --> Human 18)>,
#    <Interaction (5619 --> Human 18)>,
#    <Interaction (474 --> Human 18)>,
#    <Interaction (3289 --> Human 18)>,
#    <Interaction (5604 --> Human 18)>,
#    <Interaction (3284 --> Human 18)>,
#    <Interaction (470 --> Human 18)>,
#    <Interaction (407 --> Human 18)>,
#    <Interaction (5593 --> Human 18)>,
#    <Interaction (3290 --> Human 18)>,
#    <Interaction (5595 --> Human 18)>,
#    <Interaction (5596 --> Human 18)>,
#    <Interaction (5598 --> Human 18)>,
#    <Interaction (5599 --> Human 18)>,
#    <Interaction (5622 --> Human 18)>,
#    <Interaction (5590 --> Human 18)>,
#    <Interaction (9445 --> Human 18)>,
#    <Interaction (5616 --> Human 18)>,
#    <Interaction (10351 --> Human 18)>,
#    <Interaction (10443 --> Human 18)>,
#    <Interaction (11153 --> Human 18)>,
#    <Interaction (11221 --> Human 18)>,
#    <Interaction (11222 --> Human 18)>,
#    <Interaction (8895 --> Human 18)>,
#    <Interaction (9813 --> Human 18)>,
#    <Interaction (404 --> Human 18)>,
#    <Interaction (6560 --> Human 18)>,
#    <Interaction (369 --> Human 18)>,
#    <Interaction (376 --> Human 18)>,
#    <Interaction (378 --> Human 18)>,
#    <Interaction (381 --> Human 18)>,
#    <Interaction (382 --> Human 18)>,
#    <Interaction (383 --> Human 18)>,
#    <Interaction (385 --> Human 18)>,
#    <Interaction (387 --> Human 18)>,
#    <Interaction (388 --> Human 18)>,
#    <Interaction (389 --> Human 18)>,
#    <Interaction (404 --> Human 18)>,
#    <Interaction (413 --> Human 18)>,
#    <Interaction (374 --> Human 18)>,
#    <Interaction (380 --> Human 18)>,
#    <Interaction (406 --> Human 18)>,
#    <Interaction (415 --> Human 18)>,
#    <Interaction (372 --> Human 18)>,
#    <Interaction (386 --> Human 18)>,
#    <Interaction (8419 --> Human 18)>,
#    <Interaction (9530 --> Human 18)>]},
#  19: {'target': <Target 19 (A<sub>2A</sub> receptor)>,
#   'interactions': [<Interaction (10193 --> Human 19)>,
#    <Interaction (10193 --> Human 19)>,
#    <Interaction (4252 --> Human 19)>,
#    <Interaction (10190 --> Human 19)>,
#    <Interaction (372 --> Human 19)>,
#    <Interaction (373 --> Human 19)>,
#    <Interaction (374 --> Human 19)>,
#    <Interaction (422 --> Human 19)>,
#    <Interaction (386 --> Human 19)>,
#    <Interaction (424 --> Human 19)>,
#    <Interaction (403 --> Human 19)>,
#    <Interaction (455 --> Human 19)>,
#    <Interaction (413 --> Human 19)>,
#    <Interaction (377 --> Human 19)>,
#    <Interaction (457 --> Human 19)>,
#    <Interaction (3288 --> Human 19)>,
#    <Interaction (3289 --> Human 19)>,
#    <Interaction (459 --> Human 19)>,
#    <Interaction (5603 --> Human 19)>,
#    <Interaction (5604 --> Human 19)>,
#    <Interaction (3285 --> Human 19)>,
#    <Interaction (5605 --> Human 19)>,
#    <Interaction (5606 --> Human 19)>,
#    <Interaction (449 --> Human 19)>,
#    <Interaction (3281 --> Human 19)>,
#    <Interaction (5610 --> Human 19)>,
#    <Interaction (5612 --> Human 19)>,
#    <Interaction (5613 --> Human 19)>,
#    <Interaction (5614 --> Human 19)>,
#    <Interaction (3284 --> Human 19)>,
#    <Interaction (5615 --> Human 19)>,
#    <Interaction (5616 --> Human 19)>,
#    <Interaction (5617 --> Human 19)>,
#    <Interaction (5618 --> Human 19)>,
#    <Interaction (5619 --> Human 19)>,
#    <Interaction (407 --> Human 19)>,
#    <Interaction (5620 --> Human 19)>,
#    <Interaction (474 --> Human 19)>,
#    <Interaction (390 --> Human 19)>,
#    <Interaction (5607 --> Human 19)>,
#    <Interaction (5608 --> Human 19)>,
#    <Interaction (3290 --> Human 19)>,
#    <Interaction (5590 --> Human 19)>,
#    <Interaction (5593 --> Human 19)>,
#    <Interaction (5595 --> Human 19)>,
#    <Interaction (5599 --> Human 19)>,
#    <Interaction (5601 --> Human 19)>,
#    <Interaction (5622 --> Human 19)>,
#    <Interaction (5596 --> Human 19)>,
#    <Interaction (470 --> Human 19)>,
#    <Interaction (10351 --> Human 19)>,
#    <Interaction (380 --> Human 19)>,
#    <Interaction (10443 --> Human 19)>,
#    <Interaction (11153 --> Human 19)>,
#    <Interaction (11154 --> Human 19)>,
#    <Interaction (369 --> Human 19)>,
#    <Interaction (414 --> Human 19)>,
#    <Interaction (415 --> Human 19)>,
#    <Interaction (416 --> Human 19)>,
#    <Interaction (417 --> Human 19)>,
#    <Interaction (418 --> Human 19)>,
#    <Interaction (419 --> Human 19)>,
#    <Interaction (420 --> Human 19)>,
#    <Interaction (423 --> Human 19)>,
#    <Interaction (378 --> Human 19)>,
#    <Interaction (425 --> Human 19)>,
#    <Interaction (426 --> Human 19)>,
#    <Interaction (427 --> Human 19)>,
#    <Interaction (428 --> Human 19)>,
#    <Interaction (392 --> Human 19)>,
#    <Interaction (393 --> Human 19)>,
#    <Interaction (395 --> Human 19)>,
#    <Interaction (396 --> Human 19)>,
#    <Interaction (397 --> Human 19)>,
#    <Interaction (398 --> Human 19)>,
#    <Interaction (429 --> Human 19)>,
#    <Interaction (399 --> Human 19)>,
#    <Interaction (400 --> Human 19)>,
#    <Interaction (401 --> Human 19)>,
#    <Interaction (402 --> Human 19)>,
#    <Interaction (431 --> Human 19)>,
#    <Interaction (432 --> Human 19)>,
#    <Interaction (384 --> Human 19)>,
#    <Interaction (409 --> Human 19)>,
#    <Interaction (410 --> Human 19)>,
#    <Interaction (411 --> Human 19)>,
#    <Interaction (412 --> Human 19)>,
#    <Interaction (433 --> Human 19)>,
#    <Interaction (404 --> Human 19)>,
#    <Interaction (375 --> Human 19)>,
#    <Interaction (2844 --> Human 19)>,
#    <Interaction (405 --> Human 19)>,
#    <Interaction (3283 --> Human 19)>,
#    <Interaction (8420 --> Human 19)>,
#    <Interaction (5611 --> Human 19)>,
#    <Interaction (9236 --> Human 19)>]},
#  20: {'target': <Target 20 (A<sub>2B</sub> receptor)>,
#   'interactions': [<Interaction (384 --> Human 20)>,
#    <Interaction (372 --> Human 20)>,
#    <Interaction (386 --> Human 20)>,
#    <Interaction (390 --> Human 20)>,
#    <Interaction (453 --> Human 20)>,
# ...
#    <Interaction (1888 --> Human 346)>,
#    <Interaction (1984 --> Human 346)>,
#    <Interaction (1986 --> Human 346)>,
#    <Interaction (1980 --> Human 346)>,
#    <Interaction (1987 --> Human 346)>,
#    <Interaction (1983 --> Human 346)>,
#    <Interaction (1979 --> Human 346)>,
#    <Interaction (1976 --> Human 346)>,
#    <Interaction (1938 --> Human 346)>]},
#  255: {'target': <Target 255 (TSH receptor)>,
#   'interactions': [<Interaction (3806 --> Human 255)>,
#    <Interaction (3920 --> Human 255)>,
#    <Interaction (9113 --> Human 255)>]},
#  365: {'target': <Target 365 (UT receptor)>,
#   'interactions': [<Interaction (2156 --> Human 365)>,
#    <Interaction (2161 --> Human 365)>,
#    <Interaction (2153 --> Human 365)>,
#    <Interaction (2158 --> Human 365)>,
#    <Interaction (8872 --> Human 365)>,
#    <Interaction (2152 --> Human 365)>,
#    <Interaction (10886 --> Human 365)>,
#    <Interaction (2154 --> Human 365)>,
#    <Interaction (2155 --> Human 365)>,
#    <Interaction (2156 --> Human 365)>,
#    <Interaction (2159 --> Human 365)>,
#    <Interaction (2162 --> Human 365)>,
#    <Interaction (2166 --> Human 365)>,
#    <Interaction (2163 --> Human 365)>,
#    <Interaction (2160 --> Human 365)>,
#    <Interaction (2151 --> Human 365)>,
#    <Interaction (2167 --> Human 365)>,
#    <Interaction (2165 --> Human 365)>,
#    <Interaction (3501 --> Human 365)>,
#    <Interaction (3516 --> Human 365)>,
#    <Interaction (3531 --> Human 365)>,
#    <Interaction (9437 --> Human 365)>,
#    <Interaction (9436 --> Human 365)>,
#    <Interaction (9441 --> Human 365)>,
#    <Interaction (9440 --> Human 365)>]},
#  371: {'target': <Target 371 (VPAC<sub>1</sub> receptor)>,
#   'interactions': [<Interaction (2277 --> Human 371)>,
#    <Interaction (2261 --> Human 371)>,
#    <Interaction (2278 --> Human 371)>,
#    <Interaction (2268 --> Human 371)>,
#    <Interaction (2268 --> Human 371)>,
#    <Interaction (2273 --> Human 371)>,
#    <Interaction (2275 --> Human 371)>,
#    <Interaction (1155 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (3293 --> Human 371)>,
#    <Interaction (2272 --> Human 371)>,
#    <Interaction (2266 --> Human 371)>,
#    <Interaction (2278 --> Human 371)>,
#    <Interaction (2276 --> Human 371)>,
#    <Interaction (2276 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (2258 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (2258 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (2258 --> Human 371)>,
#    <Interaction (2270 --> Human 371)>,
#    <Interaction (2274 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2259 --> Human 371)>,
#    <Interaction (2259 --> Human 371)>,
#    <Interaction (2259 --> Human 371)>,
#    <Interaction (1155 --> Human 371)>,
#    <Interaction (2280 --> Human 371)>,
#    <Interaction (2271 --> Human 371)>,
#    <Interaction (2269 --> Human 371)>,
#    <Interaction (2269 --> Human 371)>,
#    <Interaction (2268 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2259 --> Human 371)>,
#    <Interaction (2259 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2257 --> Human 371)>,
#    <Interaction (1152 --> Human 371)>,
#    <Interaction (2272 --> Human 371)>,
#    <Interaction (3842 --> Human 371)>,
#    <Interaction (3842 --> Human 371)>,
#    <Interaction (2280 --> Human 371)>,
#    <Interaction (1155 --> Human 371)>,
#    <Interaction (2272 --> Human 371)>,
#    <Interaction (2278 --> Human 371)>,
#    <Interaction (2278 --> Human 371)>,
#    <Interaction (3842 --> Human 371)>,
#    <Interaction (2268 --> Human 371)>]},
#  372: {'target': <Target 372 (VPAC<sub>2</sub> receptor)>,
#   'interactions': [<Interaction (2264 --> Human 372)>,
#    <Interaction (2261 --> Human 372)>,
#    <Interaction (2277 --> Human 372)>,
#    <Interaction (1155 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (2278 --> Human 372)>,
#    <Interaction (2272 --> Human 372)>,
#    <Interaction (2278 --> Human 372)>,
#    <Interaction (2268 --> Human 372)>,
#    <Interaction (2266 --> Human 372)>,
#    <Interaction (2278 --> Human 372)>,
#    <Interaction (2278 --> Human 372)>,
#    <Interaction (2273 --> Human 372)>,
#    <Interaction (2275 --> Human 372)>,
#    <Interaction (1155 --> Human 372)>,
#    <Interaction (2280 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (2258 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (2258 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (2272 --> Human 372)>,
#    <Interaction (2272 --> Human 372)>,
#    <Interaction (3842 --> Human 372)>,
#    <Interaction (2271 --> Human 372)>,
#    <Interaction (2269 --> Human 372)>,
#    <Interaction (2281 --> Human 372)>,
#    <Interaction (2269 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (2268 --> Human 372)>,
#    <Interaction (2259 --> Human 372)>,
#    <Interaction (2259 --> Human 372)>,
#    <Interaction (3842 --> Human 372)>,
#    <Interaction (3842 --> Human 372)>,
#    <Interaction (2276 --> Human 372)>,
#    <Interaction (3293 --> Human 372)>,
#    <Interaction (2257 --> Human 372)>,
#    <Interaction (1152 --> Human 372)>,
#    <Interaction (2272 --> Human 372)>,
#    <Interaction (2276 --> Human 372)>,
#    <Interaction (2259 --> Human 372)>]},
#  366: {'target': <Target 366 (V<sub>1A</sub> receptor)>,
#   'interactions': [<Interaction (3482 --> Human 366)>,
#    <Interaction (2172 --> Human 366)>,
#    <Interaction (2203 --> Human 366)>,
#    <Interaction (2168 --> Human 366)>,
#    <Interaction (2184 --> Human 366)>,
#    <Interaction (2175 --> Human 366)>,
#    <Interaction (10444 --> Human 366)>,
#    <Interaction (2207 --> Human 366)>,
#    <Interaction (10615 --> Human 366)>,
#    <Interaction (2173 --> Human 366)>,
#    <Interaction (2174 --> Human 366)>,
#    <Interaction (2176 --> Human 366)>,
#    <Interaction (2179 --> Human 366)>,
#    <Interaction (2180 --> Human 366)>,
#    <Interaction (2181 --> Human 366)>,
#    <Interaction (2182 --> Human 366)>,
#    <Interaction (2183 --> Human 366)>,
#    <Interaction (2185 --> Human 366)>,
#    <Interaction (2187 --> Human 366)>,
#    <Interaction (2190 --> Human 366)>,
#    <Interaction (2192 --> Human 366)>,
#    <Interaction (2193 --> Human 366)>,
#    <Interaction (2194 --> Human 366)>,
#    <Interaction (2195 --> Human 366)>,
#    <Interaction (2196 --> Human 366)>,
#    <Interaction (2197 --> Human 366)>,
#    <Interaction (2198 --> Human 366)>,
#    <Interaction (2199 --> Human 366)>,
#    <Interaction (2201 --> Human 366)>,
#    <Interaction (2202 --> Human 366)>,
#    <Interaction (2204 --> Human 366)>,
#    <Interaction (2205 --> Human 366)>,
#    <Interaction (2206 --> Human 366)>,
#    <Interaction (2208 --> Human 366)>,
#    <Interaction (2209 --> Human 366)>,
#    <Interaction (2210 --> Human 366)>,
#    <Interaction (2211 --> Human 366)>,
#    <Interaction (2212 --> Human 366)>,
#    <Interaction (2213 --> Human 366)>,
#    <Interaction (2214 --> Human 366)>,
#    <Interaction (2215 --> Human 366)>,
#    <Interaction (2216 --> Human 366)>,
#    <Interaction (2217 --> Human 366)>,
#    <Interaction (2218 --> Human 366)>,
#    <Interaction (2219 --> Human 366)>,
#    <Interaction (2220 --> Human 366)>,
#    <Interaction (2221 --> Human 366)>,
#    <Interaction (2222 --> Human 366)>,
#    <Interaction (2223 --> Human 366)>,
#    <Interaction (2225 --> Human 366)>,
#    <Interaction (2226 --> Human 366)>,
#    <Interaction (2171 --> Human 366)>,
#    <Interaction (2200 --> Human 366)>,
#    <Interaction (2169 --> Human 366)>,
#    <Interaction (3867 --> Human 366)>,
#    <Interaction (3813 --> Human 366)>,
#    <Interaction (8529 --> Human 366)>]},
#  367: {'target': <Target 367 (V<sub>1B</sub> receptor)>,
#   'interactions': [<Interaction (2175 --> Human 367)>,
#    <Interaction (2168 --> Human 367)>,
#    <Interaction (2202 --> Human 367)>,
#    <Interaction (2184 --> Human 367)>,
#    <Interaction (2169 --> Human 367)>,
#    <Interaction (2227 --> Human 367)>,
#    <Interaction (2180 --> Human 367)>,
#    <Interaction (2181 --> Human 367)>,
#    <Interaction (2182 --> Human 367)>,
#    <Interaction (2183 --> Human 367)>,
#    <Interaction (2185 --> Human 367)>,
#    <Interaction (2190 --> Human 367)>,
#    <Interaction (2195 --> Human 367)>,
#    <Interaction (2197 --> Human 367)>,
#    <Interaction (2199 --> Human 367)>,
#    <Interaction (2200 --> Human 367)>,
#    <Interaction (2204 --> Human 367)>,
#    <Interaction (2205 --> Human 367)>,
#    <Interaction (2208 --> Human 367)>,
#    <Interaction (2209 --> Human 367)>,
#    <Interaction (2210 --> Human 367)>,
#    <Interaction (2211 --> Human 367)>,
#    <Interaction (2212 --> Human 367)>,
#    <Interaction (2213 --> Human 367)>,
#    <Interaction (2214 --> Human 367)>,
#    <Interaction (2215 --> Human 367)>,
#    <Interaction (2217 --> Human 367)>,
#    <Interaction (2219 --> Human 367)>,
#    <Interaction (2221 --> Human 367)>,
#    <Interaction (2222 --> Human 367)>,
#    <Interaction (2223 --> Human 367)>,
#    <Interaction (2191 --> Human 367)>,
#    <Interaction (2225 --> Human 367)>,
#    <Interaction (2187 --> Human 367)>,
#    <Interaction (2174 --> Human 367)>,
#    <Interaction (2172 --> Human 367)>,
#    <Interaction (2176 --> Human 367)>,
#    <Interaction (3483 --> Human 367)>]},
#  368: {'target': <Target 368 (V<sub>2</sub> receptor)>,
#   'interactions': [<Interaction (2168 --> Human 368)>,
#    <Interaction (2184 --> Human 368)>,
#    <Interaction (2234 --> Human 368)>,
#    <Interaction (2175 --> Human 368)>,
#    <Interaction (2228 --> Human 368)>,
#    <Interaction (8529 --> Human 368)>,
#    <Interaction (2182 --> Human 368)>,
#    <Interaction (10444 --> Human 368)>,
#    <Interaction (10615 --> Human 368)>,
#    <Interaction (3869 --> Human 368)>,
#    <Interaction (2226 --> Human 368)>,
#    <Interaction (2197 --> Human 368)>,
#    <Interaction (2170 --> Human 368)>,
#    <Interaction (2174 --> Human 368)>,
#    <Interaction (2176 --> Human 368)>,
#    <Interaction (2178 --> Human 368)>,
#    <Interaction (2180 --> Human 368)>,
#    <Interaction (2181 --> Human 368)>,
#    <Interaction (2183 --> Human 368)>,
#    <Interaction (2185 --> Human 368)>,
#    <Interaction (2187 --> Human 368)>,
#    <Interaction (2190 --> Human 368)>,
#    <Interaction (2195 --> Human 368)>,
#    <Interaction (2196 --> Human 368)>,
#    <Interaction (2198 --> Human 368)>,
#    <Interaction (2229 --> Human 368)>,
#    <Interaction (2200 --> Human 368)>,
#    <Interaction (2202 --> Human 368)>,
#    <Interaction (2204 --> Human 368)>,
#    <Interaction (2205 --> Human 368)>,
#    <Interaction (2169 --> Human 368)>,
#    <Interaction (2232 --> Human 368)>,
#    <Interaction (2172 --> Human 368)>,
#    <Interaction (2233 --> Human 368)>,
#    <Interaction (2208 --> Human 368)>,
#    <Interaction (2209 --> Human 368)>,
#    <Interaction (2210 --> Human 368)>,
#    <Interaction (2211 --> Human 368)>,
#    <Interaction (2212 --> Human 368)>,
#    <Interaction (2213 --> Human 368)>,
#    <Interaction (2214 --> Human 368)>,
#    <Interaction (2215 --> Human 368)>,
#    <Interaction (2235 --> Human 368)>,
#    <Interaction (2237 --> Human 368)>,
#    <Interaction (2216 --> Human 368)>,
#    <Interaction (2217 --> Human 368)>,
#    <Interaction (2219 --> Human 368)>,
#    <Interaction (2221 --> Human 368)>,
#    <Interaction (2222 --> Human 368)>,
#    <Interaction (2223 --> Human 368)>,
#    <Interaction (2225 --> Human 368)>,
#    <Interaction (2173 --> Human 368)>,
#    <Interaction (2236 --> Human 368)>,
#    <Interaction (3537 --> Human 368)>,
#    <Interaction (2238 --> Human 368)>,
#    <Interaction (3817 --> Human 368)>,
#    <Interaction (2203 --> Human 368)>,
#    <Interaction (2199 --> Human 368)>]},
#  75: {'target': <Target 75 (XCR1)>,
#   'interactions': [<Interaction (857 --> Human 75)>,
#    <Interaction (3647 --> Human 75)>,
#    <Interaction (4370 --> Human 75)>]},
#  305: {'target': <Target 305 (Y<sub>1</sub> receptor)>,
#   'interactions': [<Interaction (3762 --> Human 305)>,
#    <Interaction (1520 --> Human 305)>,
#    <Interaction (3474 --> Human 305)>,
#    <Interaction (1546 --> Human 305)>,
#    <Interaction (1527 --> Human 305)>,
#    <Interaction (1504 --> Human 305)>,
#    <Interaction (1514 --> Human 305)>,
#    <Interaction (1545 --> Human 305)>,
#    <Interaction (3848 --> Human 305)>,
#    <Interaction (1505 --> Human 305)>,
#    <Interaction (1520 --> Human 305)>,
#    <Interaction (1522 --> Human 305)>,
#    <Interaction (1530 --> Human 305)>,
#    <Interaction (1485 --> Human 305)>,
#    <Interaction (1528 --> Human 305)>]},
#  306: {'target': <Target 306 (Y<sub>2</sub> receptor)>,
#   'interactions': [<Interaction (1504 --> Human 306)>,
#    <Interaction (1549 --> Human 306)>,
#    <Interaction (1515 --> Human 306)>,
#    <Interaction (1516 --> Human 306)>,
#    <Interaction (3627 --> Human 306)>,
#    <Interaction (1504 --> Human 306)>,
#    <Interaction (1514 --> Human 306)>,
#    <Interaction (1517 --> Human 306)>,
#    <Interaction (3802 --> Human 306)>,
#    <Interaction (1534 --> Human 306)>,
#    <Interaction (1505 --> Human 306)>,
#    <Interaction (1507 --> Human 306)>,
#    <Interaction (1536 --> Human 306)>,
#    <Interaction (1508 --> Human 306)>,
#    <Interaction (1538 --> Human 306)>,
#    <Interaction (1539 --> Human 306)>,
#    <Interaction (1540 --> Human 306)>,
#    <Interaction (1510 --> Human 306)>,
#    <Interaction (1514 --> Human 306)>,
#    <Interaction (1518 --> Human 306)>,
#    <Interaction (1519 --> Human 306)>,
#    <Interaction (1522 --> Human 306)>,
#    <Interaction (1544 --> Human 306)>,
#    <Interaction (1545 --> Human 306)>,
#    <Interaction (1524 --> Human 306)>,
#    <Interaction (1527 --> Human 306)>,
#    <Interaction (1546 --> Human 306)>,
#    <Interaction (1547 --> Human 306)>,
#    <Interaction (3504 --> Human 306)>]},
#  307: {'target': <Target 307 (Y<sub>4</sub> receptor)>,
#   'interactions': [<Interaction (1512 --> Human 307)>,
#    <Interaction (3800 --> Human 307)>,
#    <Interaction (1514 --> Human 307)>,
#    <Interaction (1529 --> Human 307)>,
#    <Interaction (1504 --> Human 307)>,
#    <Interaction (1507 --> Human 307)>,
#    <Interaction (1508 --> Human 307)>,
#    <Interaction (1511 --> Human 307)>,
#    <Interaction (1513 --> Human 307)>,
#    <Interaction (1520 --> Human 307)>,
#    <Interaction (1522 --> Human 307)>,
#    <Interaction (1545 --> Human 307)>,
#    <Interaction (1546 --> Human 307)>,
#    <Interaction (8494 --> Human 307)>]},
#  308: {'target': <Target 308 (Y<sub>5</sub> receptor)>,
#   'interactions': [<Interaction (1549 --> Human 308)>,
#    <Interaction (1507 --> Human 308)>,
#    <Interaction (1557 --> Human 308)>,
#    <Interaction (1510 --> Human 308)>,
#    <Interaction (1512 --> Human 308)>,
#    <Interaction (1513 --> Human 308)>,
#    <Interaction (1515 --> Human 308)>,
#    <Interaction (1516 --> Human 308)>,
#    <Interaction (1554 --> Human 308)>,
#    <Interaction (1544 --> Human 308)>,
#    <Interaction (1524 --> Human 308)>,
#    <Interaction (1561 --> Human 308)>,
#    <Interaction (1563 --> Human 308)>,
#    <Interaction (1522 --> Human 308)>,
#    <Interaction (1527 --> Human 308)>,
#    <Interaction (1565 --> Human 308)>,
#    <Interaction (1504 --> Human 308)>]}}

# %%
for key, value in target_interactions.items():
    target = value["target"]
    print(re.sub("[ -]","_", target.name(strip_html=True)))
    print(len(value["interactions"]))

# %%
data_path = "DATA_old/"

if not path.exists(data_path):
    os.mkdir(data_path)

    
for i in range(1, 60):    
    try:     
        
        for key, value in dict(target_interactions).items():
            target = value["target"]

            receptor_name = unidecode(re.sub("[ -/]","_", target.name(strip_html=True)))
            receptor_path = data_path+receptor_name+"/"

            if not path.exists(receptor_path):
                os.mkdir(receptor_path)

            ligands_path = receptor_path+"Ligands/"

            if not path.exists(ligands_path):
                os.mkdir(ligands_path)

            interactions = value["interactions"]
            for interaction in list(interactions):
                ligand = interaction.ligand()

                pubchem_id = None
                if(ligand is not None):
                    pubchem_id = get_pubchem_id(ligand)

                ligand_path = None
                if(pubchem_id and pcp.get_properties(identifier=pubchem_id, properties="ConformerCount3D")[0]["ConformerCount3D"] != 0):
                    ligand_path = ligands_path + str(ligand.ligand_id()) + "_" + re.sub(" ", "_", interaction.action().lower()) + ".sdf"

                    if not os.path.isfile(ligand_path):
                        pcp.download("sdf", ligand_path, pubchem_id, record_type="3d")                
                        print(ligand_path)
                interactions.remove(interaction)
            del target_interactions[key]

    except Exception as e:
        print(e)
        print('Restarting!')
        time.sleep(60)
        continue
# Out:
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# DATA_old/M5_receptor/Ligands/10104_antagonist.sdf
# DATA_old/M5_receptor/Ligands/10129_antagonist.sdf
# DATA_old/M5_receptor/Ligands/298_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/305_partial_agonist.sdf
# DATA_old/M5_receptor/Ligands/3274_antagonist.sdf
# DATA_old/M5_receptor/Ligands/317_antagonist.sdf
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# DATA_old/M5_receptor/Ligands/309_antagonist.sdf
# DATA_old/M5_receptor/Ligands/3264_antagonist.sdf
# DATA_old/M5_receptor/Ligands/318_antagonist.sdf
# DATA_old/M5_receptor/Ligands/3257_positive.sdf
# DATA_old/M5_receptor/Ligands/7459_antagonist.sdf
# DATA_old/M5_receptor/Ligands/7549_antagonist.sdf
# ('Connection aborted.', BadStatusLine('<html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><title>Page not available</title><style type="text/css"><!-- *{font:14px Arial,Helvetica,sans-serif;margin:0;padding:0;}body{background-color:#e6e6e6;}h1{font-size:30px;}h2{font-size:21px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}h2,h3{color:#D03;}h3{font-size:18px;font-weight:bold;font-family:\'lucida grande\', \'tahoma\', arial, helvetica, sans-serif;}#c{background-color:#fff;padding:40px;}#f{color:#fff;background-color:#666;padding:14px;}#g{font-size:12px;}#g,#c{margin:0 auto;width:800px;}h1,h2,h3,#h,p,li{padding:0 0 14px 0}li{margin:0 0 0 20px;list-style-type:square;color:red;}li span{color:#000;} --> </style></head><body><div id="c"><div id="h"><h1 id="h1o">The University of Edinburgh</h1></div><div id="e"><h2>Page unavailable</h2><p>We\'re sorry, the page you requested is currently unavailable. We apologise for this and hope to resolve the problem soon.</p><ul><li><span>Further details can be found on the <a href="http://reports.is.ed.ac.uk/alerts/Service_status.cfm">Service Status</a> page.</span></li></ul><h3>Help</h3><ul><li><span>If you need advice quickly, the University main phone number is +44 (0)131 650 1000.</span></li><li><span>Search the University website: <a href="http://www.ed.ac.uk/search">telephone &amp; email directories</a> or <a href="http://www.ed.ac.uk/schools-departments">Departments &amp; Academic Units</a></span></li><li><span>MyEd may still be available: <a href="https://www.myed.ed.ac.uk/">Log in to MyEd</a></span></li></ul></div></div><div id="f"><div id="g">Unless explicitly stated otherwise, all material is copyright &copy; The University of Edinburgh 2013</div></div></body></html>'))
# Restarting!
# DATA_old/M5_receptor/Ligands/7632_positive.sdf
# DATA_old/M5_receptor/Ligands/8687_positive.sdf
# DATA_old/M5_receptor/Ligands/307_antagonist.sdf
# DATA_old/M5_receptor/Ligands/320_antagonist.sdf
# DATA_old/M5_receptor/Ligands/308_antagonist.sdf
# DATA_old/M5_receptor/Ligands/310_antagonist.sdf
# DATA_old/M5_receptor/Ligands/322_antagonist.sdf
# DATA_old/M5_receptor/Ligands/323_antagonist.sdf
# DATA_old/M5_receptor/Ligands/325_antagonist.sdf
# DATA_old/M5_receptor/Ligands/331_antagonist.sdf
# DATA_old/M5_receptor/Ligands/321_antagonist.sdf
# DATA_old/M5_receptor/Ligands/328_antagonist.sdf
# DATA_old/M5_receptor/Ligands/324_antagonist.sdf
# DATA_old/M5_receptor/Ligands/286_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/288_partial_agonist.sdf
# DATA_old/M5_receptor/Ligands/291_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/292_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/293_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/294_full_agonist.sdf
# DATA_old/M5_receptor/Ligands/301_partial_agonist.sdf
# DATA_old/M5_receptor/Ligands/306_partial_agonist.sdf
# DATA_old/M5_receptor/Ligands/57_partial_agonist.sdf
# DATA_old/V2_receptor/Ligands/10615_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2226_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2197_inverse_agonist.sdf
# DATA_old/V2_receptor/Ligands/2196_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2198_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2200_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2202_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2204_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2205_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2173_full_agonist.sdf
# DATA_old/V2_receptor/Ligands/3537_full_agonist.sdf
# DATA_old/V2_receptor/Ligands/2238_inverse_agonist.sdf
# DATA_old/V2_receptor/Ligands/2203_antagonist.sdf
# DATA_old/V2_receptor/Ligands/2199_antagonist.sdf
# DATA_old/Y1_receptor/Ligands/3474_antagonist.sdf
# DATA_old/Y1_receptor/Ligands/1485_antagonist.sdf
# DATA_old/Y2_receptor/Ligands/3504_antagonist.sdf
# DATA_old/Y4_receptor/Ligands/8494_positive.sdf
# DATA_old/Y5_receptor/Ligands/1563_antagonist.sdf
# DATA_old/Y5_receptor/Ligands/1565_antagonist.sdf

# %% [markdown]
# ### Delete elements on the dict that doesn't have a pdb

# %%
print("Receptors without pdb, or to be checked manually")
for key, value in dict(target_interactions).items():
    target = value["target"]
    pdbs = target.gtop_pdbs()
    if pdbs:
        target_interactions[key]["pdbs"] = pdbs
    else:
        print(re.sub("[ -]","_", target.name(strip_html=True)))
        del target_interactions[key]
# Out:
# 5_HT1B_receptor
# 5_HT1D_receptor
# 5_HT2A_receptor
# 5_HT2B_receptor
# 5_HT2C_receptor
# 5_HT6_receptor
# 5_HT7_receptor
# A1_receptor
# A2A_receptor
# A2B_receptor
# A3_receptor
# δ_receptor
# D2_receptor
# D3_receptor
# EP4_receptor
# GAL1_receptor
# GAL2_receptor
# GnRH1_receptor
# H1_receptor
# H3_receptor
# κ_receptor
# mGlu5_receptor
# M1_receptor
# M2_receptor
# M3_receptor
# M4_receptor
# M5_receptor
# μ_receptor
# SST2_receptor
# SST3_receptor
# VPAC1_receptor
# VPAC2_receptor
# V1A_receptor
# V2_receptor

# %% [markdown]
# ### Download all pdb on the receptor folder inside the data folder

# %%
data_path = "DATA/"

if not path.exists(data_path):
    os.mkdir(data_path)

for key, value in target_interactions.items():
    target = value["target"]
    
    receptor_name = unidecode(re.sub("[ -]","_", target.name(strip_html=True)))    
    receptor_path = data_path+receptor_name+"/"
    
    if not path.exists(receptor_path):
        os.mkdir(receptor_path)
    
    for pdb_id in value["pdbs"]:
        pdb_id, ppdb = update_pdb_obsolete(pdb_id)
        
        pdb_path = receptor_path+pdb_id+".pdb"
        if not os.path.isfile(pdb_path):
            ppdb.to_pdb(path=pdb_path, 
                records=None, 
                gz=False, 
                append_newline=True)  
            print(pdb_path)

# %% [markdown]
# ### Download all ligands on the ligands folder of the receptor folder

# %%
data_path = "DATA/"

if not path.exists(data_path):
    os.mkdir(data_path)

for key, value in target_interactions.items():
    target = value["target"]
    
    receptor_name = unidecode(re.sub("[ -]","_", target.name(strip_html=True)))    
    receptor_path = data_path+receptor_name+"/"

    if not path.exists(receptor_path):
        os.mkdir(receptor_path)

    ligands_path = receptor_path+"Ligands/"
    
    if not path.exists(ligands_path):
        os.mkdir(ligands_path)
    
    for interaction in value["interactions"]:
        ligand = interaction.ligand()
        pubchem_id = get_pubchem_id(ligand)
        
        if(pubchem_id and pcp.get_properties(identifier=pubchem_id, properties="ConformerCount3D")[0]["ConformerCount3D"] != 0):
            ligand_path = ligands_path + str(ligand.ligand_id()) + "_" + re.sub(" ", "_", interaction.action().lower()) + ".sdf"
            
            if not os.path.isfile(ligand_path):
                pcp.download("sdf", ligand_path, pubchem_id, record_type="3d")                
                print(ligand_path)

# %%
target_interactions[372]["interactions"]
# Out:
# [<Interaction (2264 --> Human 372)>,
#  <Interaction (2261 --> Human 372)>,
#  <Interaction (2277 --> Human 372)>,
#  <Interaction (1155 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (2278 --> Human 372)>,
#  <Interaction (2272 --> Human 372)>,
#  <Interaction (2278 --> Human 372)>,
#  <Interaction (2268 --> Human 372)>,
#  <Interaction (2266 --> Human 372)>,
#  <Interaction (2278 --> Human 372)>,
#  <Interaction (2278 --> Human 372)>,
#  <Interaction (2273 --> Human 372)>,
#  <Interaction (2275 --> Human 372)>,
#  <Interaction (1155 --> Human 372)>,
#  <Interaction (2280 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (2258 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (2258 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (2272 --> Human 372)>,
#  <Interaction (2272 --> Human 372)>,
#  <Interaction (3842 --> Human 372)>,
#  <Interaction (2271 --> Human 372)>,
#  <Interaction (2269 --> Human 372)>,
#  <Interaction (2281 --> Human 372)>,
#  <Interaction (2269 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (2268 --> Human 372)>,
#  <Interaction (2259 --> Human 372)>,
#  <Interaction (2259 --> Human 372)>,
#  <Interaction (3842 --> Human 372)>,
#  <Interaction (3842 --> Human 372)>,
#  <Interaction (2276 --> Human 372)>,
#  <Interaction (3293 --> Human 372)>,
#  <Interaction (2257 --> Human 372)>,
#  <Interaction (1152 --> Human 372)>,
#  <Interaction (2272 --> Human 372)>,
#  <Interaction (2276 --> Human 372)>,
#  <Interaction (2259 --> Human 372)>]

# %% [markdown]
# ### Download all ligands on the ligands folder of the receptor folder

# %%
path_ligands = data_path+"ligands/"+id_pdb+"/"

if not path.exists(path_ligands):    
    os.mkdir(path_ligands)
    
for i in range(0, len(list_dict)):      
    if(pcp.get_properties(identifier=list_dict[i]["pubchem_id"], properties="ConformerCount3D")[0]["ConformerCount3D"] != 0):
        
        print(str(i)+" downloading...")
        
        pcp.download("sdf", 
                     path_ligands + str(list_dict[i]["id"]) + "_" + list_dict[i]["action"].lower() + ".sdf", 
                     list_dict[i]["pubchem_id"], record_type="3d", overwrite=True)

# %% [markdown]
# ### list of ligand with pubchem ids

# %%
list_dict = []
for interaction in interactions:
    time.sleep(1)
    pubchem_id = get_pubchem_id(interaction.ligand())
    if pubchem_id:
        list_dict.append({
            "id": interaction.ligand_id(),
            "pubchem_id": pubchem_id,
            "type": interaction.interaction_type(),
            "action": interaction.action()
        })

# %%
list_dict
# Out:
# [{'id': 86,
#   'pubchem_id': '3559',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 948,
#   'pubchem_id': '5281881',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 963,
#   'pubchem_id': '2159',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 960,
#   'pubchem_id': '643497',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 37,
#   'pubchem_id': '54746',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 35,
#   'pubchem_id': '31101',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 953,
#   'pubchem_id': '119570',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 968,
#   'pubchem_id': '5281878',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 38,
#   'pubchem_id': '2818',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 940, 'pubchem_id': '681', 'type': 'Agonist', 'action': 'Full agonist'},
#  {'id': 34,
#   'pubchem_id': '60795',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 50,
#   'pubchem_id': '5002',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 96,
#   'pubchem_id': '5073',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 33,
#   'pubchem_id': '6005',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 941, 'pubchem_id': '59227', 'type': 'Agonist', 'action': 'Agonist'},
#  {'id': 47,
#   'pubchem_id': '4585',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 59,
#   'pubchem_id': '60854',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 204,
#   'pubchem_id': '3372',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7295, 'pubchem_id': '5095', 'type': 'Agonist', 'action': 'Agonist'},
#  {'id': 7227,
#   'pubchem_id': '4078',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 5501,
#   'pubchem_id': '5355',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7124, 'pubchem_id': '2342', 'type': 'Agonist', 'action': 'Agonist'},
#  {'id': 7279,
#   'pubchem_id': '4917',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7427, 'pubchem_id': '6918314', 'type': 'Agonist', 'action': 'Agonist'},
#  {'id': 7281,
#   'pubchem_id': '4926',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 103,
#   'pubchem_id': '5736',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7556,
#   'pubchem_id': '115368',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7557,
#   'pubchem_id': '62867',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 22,
#   'pubchem_id': '163091',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 214,
#   'pubchem_id': '5566',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 209,
#   'pubchem_id': '4748',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 98,
#   'pubchem_id': '60149',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 34,
#   'pubchem_id': '60795',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 7652,
#   'pubchem_id': '56599142',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 7651,
#   'pubchem_id': '56597938',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 7670,
#   'pubchem_id': '125564',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7671,
#   'pubchem_id': '11154555',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 7672,
#   'pubchem_id': '11978813',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 90,
#   'pubchem_id': '16362',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 958,
#   'pubchem_id': '688272',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 8370,
#   'pubchem_id': '6917970',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7651,
#   'pubchem_id': '56597938',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 8369,
#   'pubchem_id': '1093278',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 7650,
#   'pubchem_id': '56593482',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 7650,
#   'pubchem_id': '56593482',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 7652,
#   'pubchem_id': '56599142',
#   'type': 'Agonist',
#   'action': 'Biased agonist'},
#  {'id': 8434,
#   'pubchem_id': '23643664',
#   'type': 'Agonist',
#   'action': 'Agonist'},
#  {'id': 8436,
#   'pubchem_id': '25107716',
#   'type': 'Agonist',
#   'action': 'Agonist'},
#  {'id': 8435,
#   'pubchem_id': '11224758',
#   'type': 'Agonist',
#   'action': 'Agonist'},
#  {'id': 9099,
#   'pubchem_id': '9821941',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 9190,
#   'pubchem_id': '71452040',
#   'type': 'Agonist',
#   'action': 'Agonist'},
#  {'id': 9189,
#   'pubchem_id': '71452041',
#   'type': 'Agonist',
#   'action': 'Agonist'},
#  {'id': 9215,
#   'pubchem_id': '16363',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 11288,
#   'pubchem_id': '130431314',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 3949,
#   'pubchem_id': '9818479',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 177,
#   'pubchem_id': '133633',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 950,
#   'pubchem_id': '1219',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 951,
#   'pubchem_id': '6604758',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 952,
#   'pubchem_id': '115107',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 43,
#   'pubchem_id': '28864',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 48,
#   'pubchem_id': '47811',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 49,
#   'pubchem_id': '4850',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 954,
#   'pubchem_id': '57242',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 52,
#   'pubchem_id': '219050',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 56,
#   'pubchem_id': '443951',
#   'type': 'Agonist',
#   'action': 'Partial agonist'},
#  {'id': 955,
#   'pubchem_id': '115007',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 956,
#   'pubchem_id': '6603800',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 957,
#   'pubchem_id': '5311190',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 62,
#   'pubchem_id': '37459',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 962,
#   'pubchem_id': '156333',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 83,
#   'pubchem_id': '2726',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 966,
#   'pubchem_id': '57267',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 44,
#   'pubchem_id': '3408722',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 963,
#   'pubchem_id': '2159',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 56,
#   'pubchem_id': '443951',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 94,
#   'pubchem_id': '3033769',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 969,
#   'pubchem_id': '167715',
#   'type': 'Agonist',
#   'action': 'Full agonist'},
#  {'id': 52,
#   'pubchem_id': '219050',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 2, 'pubchem_id': '54562', 'type': 'Agonist', 'action': 'Full agonist'},
#  {'id': 205,
#   'pubchem_id': '3964',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 7694,
#   'pubchem_id': '9910352',
#   'type': 'Allosteric modulator',
#   'action': 'Negative'},
#  {'id': 965,
#   'pubchem_id': '3151',
#   'type': 'Antagonist',
#   'action': 'Antagonist'},
#  {'id': 8368,
#   'pubchem_id': '57377246',
#   'type': 'Antagonist',
#   'action': 'Antagonist'}]

# %% [markdown]
# ### download sdf of ligands

# %%
path_ligands = "ligands/"+id_pdb+"/"
path_ligands
# Out:
# 'ligands/6CM4/'

# %%
if not path.exists(path_ligands):    
    os.mkdir(path_ligands)
    
for i in range(0, len(list_dict)):      
    if(pcp.get_properties(identifier=list_dict[i]["pubchem_id"], properties="ConformerCount3D")[0]["ConformerCount3D"] != 0):
        
        print(str(i)+" downloading...")
        
        pcp.download("sdf", 
                     path_ligands + str(list_dict[i]["id"]) + "_" + list_dict[i]["action"].lower() + ".sdf", 
                     list_dict[i]["pubchem_id"], record_type="3d", overwrite=True)
# Out:
# 0 downloading...
# 1 downloading...
# 2 downloading...
# 3 downloading...
# 4 downloading...
# 5 downloading...
# 6 downloading...
# 7 downloading...
# 8 downloading...
# 9 downloading...
# 10 downloading...
# 11 downloading...
# 12 downloading...
# 13 downloading...
# 14 downloading...
# 15 downloading...
# 16 downloading...
# 17 downloading...
# 18 downloading...
# 19 downloading...
# 20 downloading...
# 21 downloading...
# 22 downloading...
# 23 downloading...
# 24 downloading...
# 25 downloading...
# 26 downloading...
# 27 downloading...
# 28 downloading...
# 29 downloading...
# 30 downloading...
# 31 downloading...
# 32 downloading...
# 33 downloading...
# 34 downloading...
# 35 downloading...
# 36 downloading...
# 37 downloading...
# 38 downloading...
# 39 downloading...
# 40 downloading...
# 41 downloading...
# 42 downloading...
# 43 downloading...
# 44 downloading...
# 45 downloading...
# 46 downloading...
# 47 downloading...
# 48 downloading...
# 49 downloading...
# 50 downloading...
# 51 downloading...
# 52 downloading...
# 53 downloading...
# 54 downloading...
# 55 downloading...
# 56 downloading...
# 57 downloading...
# 58 downloading...
# 59 downloading...
# 60 downloading...
# 61 downloading...
# 62 downloading...
# 63 downloading...
# 64 downloading...
# 65 downloading...
# 66 downloading...
# 67 downloading...
# 68 downloading...
# 69 downloading...
# 70 downloading...
# 71 downloading...
# 72 downloading...
# 73 downloading...
# 74 downloading...
# 75 downloading...
# 76 downloading...
# 77 downloading...
# 78 downloading...
# 79 downloading...
# 80 downloading...
# 81 downloading...
# 82 downloading...

# %%
pcp.__dict__
